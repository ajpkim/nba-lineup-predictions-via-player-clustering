# %%
import time
import pandas as pd
import numpy as np

from functools import reduce

import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options

# %%
## example driver

options = Options()
options.headless = False

browser = webdriver.Firefox(executable_path="scraping/drivers/geckodriver", options=options)
browser.get('https://duckduckgo.com')

print('Title: %s' % browser.title)
browser.quit()
# Out:
# Title: DuckDuckGo — Privacy, simplified.

# %%
options = Options()
options.headless = False
browser = webdriver.Firefox(executable_path="scraping/drivers/geckodriver", options=options)
browser.get("https://www.basketball-reference.com/leagues/NBA_1999_shooting.html")

# %%
table_xpath = '//*[@id="csv_shooting_stats"]'
table = browser.find_element_by_xpath(table_xpath)

# %%
text = table.text.split(',')

# %%
text[0:50]
# Out:
# ['--- When using SR data',
#  ' please cite us and provide a link and/or a mention.\n\n\n \n',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '% of FGA by Distance',
#  '% of FGA by Distance',
#  '% of FGA by Distance',
#  '% of FGA by Distance',
#  '% of FGA by Distance',
#  '% of FGA by Distance',
#  '',
#  'FG% by Distance',
#  'FG% by Distance',
#  'FG% by Distance',
#  'FG% by Distance',
#  'FG% by Distance',
#  'FG% by Distance',
#  '',
#  "% of FG Ast'd",
#  "% of FG Ast'd",
#  '',
#  'Dunks',
#  'Dunks',
#  '',
#  'Corner 3s',
#  'Corner 3s',
#  '',
#  'Heaves',
#  'Heaves\nRk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'MP',
#  'FG%',
#  'Dist.',
#  '',
#  '2P',
#  '0-3',
#  '3-10',
#  '10-16',
#  '16-3P']

# %%
player_id_xpath = "/html/body/div[2]/div[5]/div[3]/div[2]/div/table/tbody/tr[1]/td[1]"
player_id_xpath = '/html/body/div[2]/div[5]/div[3]/div[2]/div/table/tbody/tr[1]/td[1]/a'
player_id = browser.find_element_by_xpath(player_id_xpath)
player_id.text
# Out:
# 'Tariq Abdul-Wahad'

# %%
# getting the correct 'data-stat' column names
# SO: https://stackoverflow.com/questions/54702255/using-beautifulsoup-to-find-a-attribute-called-data-stats

from bs4 import BeautifulSoup
import requests

url = "https://www.basketball-reference.com/leagues/NBA_2019_per_poss.html#per_poss_stats::none"
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# Get table
table = soup.find(class_="table_outer_container")

# Get head
thead = table.find('thead')
th_head = thead.find_all('th')

for thh in th_head:
    # Get case value
#     print(thh.get_text())

    # Get data-stat value
    print(thh.get('data-stat'))

# Get body
tbody = table.find('tbody')
tr_body = tbody.find_all('tr')

for trb in tr_body:
    # Get id
    print(trb.get('id'))

    # Get th data
    th = trb.find('th')
    print(th.get_text())
    print(th.get('data-stat'))

    for td in trb.find_all('td'):
        # Get case value
        print(td.get_text())
        # Get data-stat value
        print(td.get('data-stat'))

# Get footer
tfoot = table.find('tfoot')
thf = tfoot.find('th')

# Get case value
print(thf.get_text())
# Get data-stat value
print(thf.get('data-stat'))

for tdf in tfoot.find_all('td'):
    # Get case value
    print(tdf.get_text())
    # Get data-stat value
    print(tdf.get('data-stat'))

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.basketball-reference.com/leagues/NBA_2019_per_poss.html#per_poss_stats::none"
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# Get table
table = soup.find(class_="table_outer_container")

# Get head
thead = table.find('thead')
th_head = thead.find_all('th')

for thh in th_head:
    # Get data-stat value
    print(thh.get('data-stat'))

# Get body
tbody = table.find('tbody')
tr_body = tbody.find_all('tr')


for trb in tr_body:
    # Get id
#     print(trb.get('id'))

    # Get th data
#     th = trb.find('th')
#     print(th.get_text())
#     print(th.get('data-stat'))

    for td in trb.find_all('td'):
        # Get case value
#         print(td.get_text())
        # Get data-stat value
        print(td.get('data-append-csv'))
        
# Get body
# tbody = table.find('tbody')
# tr_body = tbody.find_all('tr')

# for trb in tr_body[0:5]:
#     # Get id
# #     print(trb.get('data-append-csv'))
#     print(trb.get_text())


# for row in table.find_all('tr')[0:5]:
#     print(row.get('data-append-csv').text)

# player_ids = soup.find("elm", class_="myclass")
# print(elm.get("class"))
# Out:
# ranker
# player
# pos
# age
# team_id
# g
# gs
# mp
# fg_per_poss
# fga_per_poss
# fg_pct
# fg3_per_poss
# fg3a_per_poss
# fg3_pct
# fg2_per_poss
# fg2a_per_poss
# fg2_pct
# ft_per_poss
# fta_per_poss
# ft_pct
# orb_per_poss
# drb_per_poss
# trb_per_poss
# ast_per_poss
# stl_per_poss
# blk_per_poss
# tov_per_poss
# pf_per_poss
# pts_per_poss
#
# off_rtg
# def_rtg
# abrinal01
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# acyqu01
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# adamsja01
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %% [markdown]
# ## converting bs4 code to selenium

# %%
th_x = '/html/body/div[2]/div[5]/div[3]/div[2]/div/table/thead'
th = browser.find_element_by_xpath(th_x)
print(th.text)
# Out:
# Rk Player Pos Age Tm G GS MP FG FGA FG% 3P 3PA 3P% 2P 2PA 2P% FT FTA FT% ORB DRB TRB AST STL BLK TOV PF PTS ORtg DRtg

# %%
from bs4 import BeautifulSoup
import requests

options = Options()
options.headless = False
browser = webdriver.Firefox(executable_path="scraping/drivers/geckodriver", options=options)
url = "https://www.basketball-reference.com/leagues/NBA_2019_per_poss.html#per_poss_stats::none"
browser.get(url)

page_source = browser.page_source

# r = requests.get(url)
soup = BeautifulSoup(page_source, 'html.parser')

# Get table
table = soup.find(class_="table_outer_container")

# table = 

# Get head
thead = table.find('thead')
th_head = thead.find_all('th')

for thh in th_head:
    # Get data-stat value
    print(thh.get('data-stat'))

# Get body
tbody = table.find('tbody')
tr_body = tbody.find_all('tr')


for trb in tr_body:
    

    # Get id
#     print(trb.get('id'))

#     # Get th data
#     th = trb.find('th')
# #     print(th.get_text())
# #     print(th.get('data-stat'))

    for td in trb.find_all('td'):
#         # Get case value
# #         print(td.get_text())
#         # Get data-stat value
#         print(td.get('data-append-csv'))
        
# Get body
# tbody = table.find('tbody')
# tr_body = tbody.find_all('tr')

# for trb in tr_body[0:5]:
#     # Get id
# #     print(trb.get('data-append-csv'))
#     print(trb.get_text())


# for row in table.find_all('tr')[0:5]:
#     print(row.get('data-append-csv').text)

# player_ids = soup.find("elm", class_="myclass")
# print(elm.get("class"))
# Out:
# ranker
# player
# pos
# age
# team_id
# g
# gs
# mp
# fg_per_poss
# fga_per_poss
# fg_pct
# fg3_per_poss
# fg3a_per_poss
# fg3_pct
# fg2_per_poss
# fg2a_per_poss
# fg2_pct
# ft_per_poss
# fta_per_poss
# ft_pct
# orb_per_poss
# drb_per_poss
# trb_per_poss
# ast_per_poss
# stl_per_poss
# blk_per_poss
# tov_per_poss
# pf_per_poss
# pts_per_poss
#
# off_rtg
# def_rtg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-6a604a014803> in <module>
#      33 for trb in tr_body:
#      34     a = trb.find_all('td')
# ---> 35     a[1].get('data-append-csv')
#      36     # Get id
#      37 #     print(trb.get('id'))
#
# IndexError: list index out of range

# %%
tx = soup.find("/html/body/div[2]/div[5]/div[3]/div[2]/div[2]/table/tbody")

# %%
tx.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-2bd50557a568> in <module>
# ----> 1 tx.get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
def get_stat_headers(soup):
    table = soup.find(class_="table_outer_container")
    thead = table.find('thead')
    thead_th = thead.find_all('th')
    stat_cols = []
    for thh in thead_th:
        col = thh.get('data-stat')
        col = col if col != '' else 'DUMMY'
        stat_cols.append(col)
    stat_cols.remove('ranker')
    return stat_cols

s = get_stat_headers(soup)
print(s)
# Out:
# ['player', 'pos', 'age', 'team_id', 'g', 'gs', 'mp', 'fg_per_poss', 'fga_per_poss', 'fg_pct', 'fg3_per_poss', 'fg3a_per_poss', 'fg3_pct', 'fg2_per_poss', 'fg2a_per_poss', 'fg2_pct', 'ft_per_poss', 'fta_per_poss', 'ft_pct', 'orb_per_poss', 'drb_per_poss', 'trb_per_poss', 'ast_per_poss', 'stl_per_poss', 'blk_per_poss', 'tov_per_poss', 'pf_per_poss', 'pts_per_poss', 'DUMMY', 'off_rtg', 'def_rtg']

# %%
def read_stat_table(soup):
    table = soup.find(class_="table_outer_container")
    tbody = table.find('tbody')
    tbody_tr = tbody.find_all('tr')
    all_stats = []
    all_ids = []
    for row in tbody_tr:
        
        player_stats = [col.text for col in row.find_all('td')]
        all_stats.append(player_stats)
        cols = row.find_all('td')
#         player_id = cols[0].get('data-append-csv')
        
#         p_id = [col.get('data-append-csv') for col in cols]
#         p_id = [pid for pid in p_id if pid != None]
#         all_ids.append(player_id)
        
    stat_cols = get_stat_headers(soup)
    df = pd.DataFrame(all_stats, columns=stat_cols).set_index('player')
#     df['id'] = all_ids
    return df

df = read_stat_table(soup)
df.head()
# Out:
#              pos age team_id   g  gs    mp fg_per_poss fga_per_poss fg_pct  \
# player
# Álex Abrines  SG  25     OKC  31   2   588         4.4         12.5   .357
# Quincy Acy    PF  28     PHO  10   0   123         1.6          7.0   .222
# Jaylen Adams  PG  22     ATL  34   1   428         4.1         11.9   .345
# Steven Adams   C  25     OKC  80  80  2669         8.4         14.1   .595
# Bam Adebayo    C  21     MIA  82  28  1913         7.2         12.4   .576
#
#              fg3_per_poss  ... trb_per_poss ast_per_poss stl_per_poss  \
# player                     ...
# Álex Abrines          3.3  ...          3.8          1.6          1.3
# Quincy Acy            0.8  ...          9.7          3.1          0.4
# Jaylen Adams          2.7  ...          6.5          7.0          1.5
# Steven Adams          0.0  ...         13.3          2.2          2.0
# Bam Adebayo           0.1  ...         15.2          4.7          1.8
#
# ...

# %%
df.head(25)
# Out:
#                          pos   age team_id     g    gs    mp fg_per_poss  \
# player
# Álex Abrines              SG    25     OKC    31     2   588         4.4
# Quincy Acy                PF    28     PHO    10     0   123         1.6
# Jaylen Adams              PG    22     ATL    34     1   428         4.1
# Steven Adams               C    25     OKC    80    80  2669         8.4
# Bam Adebayo                C    21     MIA    82    28  1913         7.2
# Deng Adel                 SF    21     CLE    19     3   194         2.8
# DeVaughn Akoon-Purcell    SG    25     DEN     7     0    22         6.7
# LaMarcus Aldridge          C    33     SAS    81    81  2687        12.4
# Rawle Alkins              SG    21     CHI    10     1   120         5.3
# Grayson Allen             SG    23     UTA    38     2   416         7.7
# Jarrett Allen              C    20     BRK    80    80  2096         7.6
# Kadeem Allen              SG    26     NYK    19     1   416         7.5
# ...

# %%
df.loc[:, 'DUMMY']
# Out:
# player
# Álex Abrines
# Quincy Acy
# Jaylen Adams
# Steven Adams
# Bam Adebayo
#                ..
# Tyler Zeller
# Ante Žižić
# Ivica Zubac
# Ivica Zubac
# Ivica Zubac
# Name: DUMMY, Length: 734, dtype: object

# %%
# soup = BeautifulSoup(page_source, 'html.parser')

# # Get table
table = soup.find(class_="table_outer_container")
# # Get head
thead = table.find('thead')
thead_th = thead.find_all('th')
stats = []


# ssss = thead_th.attrs[0]
# print(ssss)



for thh in thead_th:
    # Get data-stat value
    stats.append(thh.get('data-stat'))
#     print(thh.get('data-stat'))
stats.remove("")
print(stats)

tbody = table.find('tbody')
tbody_tr = tbody.find_all('tr')


for row in tbody_tr[0:2]:
  

    cols = row.find_all('td')
    print(len(cols))
    print(cols[0].get('data-append-csv'))

# print(row.attrs)
#     print(row.get_attribute_list('data-row'))
    
#     print(row.get_text())
#     print('-----')
#     print(row.get('blk_per_poss'))
#     print()
# #     cols = row.find_all('td')
# #     s = 
#     s = [col.text for col in row.find_all('td')]
#     print(s)
    
#     for col in cols:
#         print(col.text)
#     print(cols)
#     print(s)
    
#     for td in row.find_all('td'):
#         print(td.get_text())
# #     all_row = row.find_all('td')
# #     s = [all_row[i].text for i in range(len(all_row))]  # works but makes strings of everything!
    
#     s = [all_row[i].get_text() for i in range(len(all_row))]
# #     print(all_row[0].text)
#     print(s)
    print('\n\n')

# len(tbody_tr)


# Get body
# tbody = table.find('tbody')
# tr_body = tbody.find_all('tr')

# for row in tr_body[0:10]:
#     print()
#     for td in row.find_all('td'):
#         # Get case value
#         print(td.get('data-append-csv'))
    

# len(tr_body)
# Out:
# ['ranker', 'player', 'pos', 'age', 'team_id', 'g', 'gs', 'mp', 'fg_per_poss', 'fga_per_poss', 'fg_pct', 'fg3_per_poss', 'fg3a_per_poss', 'fg3_pct', 'fg2_per_poss', 'fg2a_per_poss', 'fg2_pct', 'ft_per_poss', 'fta_per_poss', 'ft_pct', 'orb_per_poss', 'drb_per_poss', 'trb_per_poss', 'ast_per_poss', 'stl_per_poss', 'blk_per_poss', 'tov_per_poss', 'pf_per_poss', 'pts_per_poss', 'off_rtg', 'def_rtg']
# 31
# abrinal01
#
#
#
# 31
# acyqu01

# %%
ids = soup.find_all('td')
ids = [i.get('data-append-csv') for i in ids]

# %%
ids = [i for i in ids if i != None]
len(ids)
# Out:
# 708

# %%
ids = set(ids)
len(ids)
# Out:
# 530

# %%
ids.remove(None)

# %%
## with set of stats pull out each row col stat

table = soup.find(class_="table_outer_container")
th = table.find('thead')
thh = thead.find_all('th')


# for thh in th_head:
#     # Get data-stat value
#     print(thh.get('data-stat'))

# Get body
tbody = table.find('tbody')
tr_body = tbody.find_all('tr')
for row in tr_body[0:20]:
    print(row.attrs)
    print(row['class'])
    if row['class'] != ['full_table']:
        print('\n\nSKIP ME')
    
#     row_stats = [td.get(stat) for stat in stats for td in row.find_all('td')]
#     print(row_stats)
# Out:
# {'class': ['full_table'], 'data-row': '0'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '1'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '2'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '3'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '4'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '5'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '6'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '7'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '8'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '9'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '10'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '11'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '12'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '13'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '14'}
# ['full_table']
# {'class': ['full_table'], 'data-row': '15'}
# ['full_table']
# ...

# %%
tbody.text.split('\n')
# Out:
# ['',
#  '1Álex AbrinesSG25OKC3125884.412.5.3573.310.1.3231.22.4.5001.01.0.9230.43.43.81.61.30.51.14.213.1103111',
#  '2Quincy AcyPF28PHO1001231.67.0.2220.85.8.1330.81.2.6672.73.9.7001.28.59.73.10.41.61.69.36.687116',
#  '3Jaylen AdamsPG22ATL3414284.111.9.3452.78.0.3381.43.9.3610.81.0.7781.25.36.57.01.50.53.04.911.799115',
#  '4Steven AdamsC25OKC808026698.414.1.5950.00.0.0008.414.1.5962.65.1.5006.86.513.32.22.01.32.43.619.4120106',
#  '5Bam AdebayoC21MIA822819137.212.4.5760.10.4.2007.112.0.5884.25.8.7354.211.015.24.71.81.73.15.218.6120104',
#  '6Deng AdelSF21CLE1931942.89.2.3061.55.9.2611.33.3.3851.01.01.0000.84.14.91.30.31.01.53.38.285121',
#  '7DeVaughn Akoon-PurcellSG25DEN70226.722.3.3000.08.9.0006.713.4.5002.24.5.5002.26.78.913.44.50.04.58.915.684104',
#  '8LaMarcus AldridgeC33SAS8181268712.424.0.5190.20.8.23812.323.2.5286.37.5.8474.69.013.53.50.81.92.63.331.4117110',
#  '9Rawle AlkinsSG21CHI1011205.315.8.3331.24.8.2504.010.9.3703.24.8.6674.46.110.55.30.40.03.22.815.093117',
# ...

# %%
def select_season(season):
    url = f'https://www.basketball-reference.com/leagues/NBA_{season}_per_poss.html'
    browser.get(url)

def toggle_partial_rows(browser):
    button_xpath = '//*[@id="per_poss_stats_toggle_partial_table"]'
    browser.find_element_by_xpath(button_xpath).click()

def remove_mobile_fmt(browser):
    menu_xpath =  '/html/body/div[2]/div[5]/div[3]/div[1]/div/ul/li[1]/span'
    browser.find_element_by_xpath(menu_xpath).click()
    button_xpath = '/html/body/div[2]/div[5]/div[3]/div[1]/div/ul/li[1]/div/ul/li[5]/button'
    browser.find_element_by_xpath(button_xpath).click()

def select_stat_table(browser, stat_table):
    stat_table_dict = {'totals': 1, 'per game': 2, 'per 36 min': 3, 'per 100 poss': 4, 'advanced': 5, 'play-by-play': 6, 'adjusted shooting': 7}
    n = stat_table_dict[stat_table]
    button_xpath = f'/html/body/div[2]/div[5]/div[2]/div[{n}]/a'
    browser.find_element_by_xpath(button_xpath).click()

# %%
toggle_partial_rows(browser)

# %%
remove_mobile_fmt(browser)

# %%
select_season(2003)

# %%
select_stat_table(browser, 'advanced')

# %%
def read_stat_table(soup):
    table = soup.find(class_="table_outer_container")
    tbody = table.find('tbody')
    tbody_tr = tbody.find_all('tr')
    stat_cols, all_stats, all_ids = [], [], []
        
    for row in tbody_tr:
        if row['class'] != "full_table": continue  # skip partial entries for players with multiple teams
        cols = row.find_all('td')
        if stat_cols == []:
            stat_cols = [col.get('data-stat') for col in cols]
        player_stats = [col.text for col in cols]
        all_stats.append(player_stats)
        player_id = cols[0].get('data-append-csv')
        all_ids.append(player_id)

    df = pd.DataFrame(all_stats, columns=stat_cols).set_index('player')
    df['player_id'] = all_ids
    return df
