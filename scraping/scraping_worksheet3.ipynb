# %%
import time
import pandas as pd
import numpy as np

from functools import reduce

import matplotlib.pyplot as plt
# %matplotlib inline

import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options

# %%
## example headless driver

options = Options()
options.headless = True

browser = webdriver.Firefox(executable_path="./drivers/geckodriver", options=options)
browser.get('https://duckduckgo.com')

print('Title: %s' % browser.title)
browser.quit()
# Out:
# Title: DuckDuckGo — Privacy, simplified.

# %%
## functions to navigate nba.com/stats pages

def sort_by_name(browser):
    xpath_player_sort = '/html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[2]/div[1]/table/thead/tr/th[2]'
    browser.find_element_by_xpath(xpath_player_sort).click()
    browser.find_element_by_xpath(xpath_player_sort).click()
    return

def select_all_pages(browser):
    xpath_page_selection = '/html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[1]/div/div/select'
    xpath_all_pages = xpath_page_selection + '/option[1]'
    browser.find_element_by_xpath(xpath_all_pages).click()
    return

def select_per_100(browser):
    xpath_per_mode = '/html/body/main/div[2]/div/div[2]/div/div/div[1]/div[3]/div/div/label/select'
    browser.find_element_by_xpath(xpath_per_mode).click()
    
    xpath_per_100 = '/html/body/main/div[2]/div/div[2]/div/div/div[1]/div[3]/div/div/label/select/option[3]'
    browser.find_element_by_xpath(xpath_per_100).click()
    

def select_stat_type(browser, stat_type):
    """
    stat type mappings
    1: Traditional
    2: Advanced
    3: Misc
    4: Scoring
    5: Usage
    6: Opponent
    7: Defense
    """
    
    stat_table_dict = {'traditional': 1, 'advanced': 2, 'misc': 3, 'scoring': 4, 'usage': 5, 'opponent': 6, 'defense':7}
    n = stat_table_dict[stat_type]
    
    ## select the header to get drop down
    xpath_stat_type_button = '/html/body/main/div[2]/div/div[2]/div/nav-dropdown/nav/section[3]/div/a'
    browser.find_element_by_xpath(xpath_stat_type_button).click()

    ## navigate to different stat type
    xpath_stat_type = f'/html/body/main/div[2]/div/div[2]/div/nav-dropdown/nav/section[3]/ul/li[{n}]/a/span'
    browser.find_element_by_xpath(xpath_stat_type).click()
    
    if n in [1, 3, 6, 7]:
        time.sleep(2)
        select_per_100(browser)
    return

def select_season(browser, season):
    seasons_dict = dict(zip(range(2019, 1995, -1), [i for i in range(1, 100)]))
    n = seasons_dict[season]
    ## click 'SEASON' header
    xpath_season_header = '/html/body/main/div[2]/div/div[2]/div/div/div[1]/div[1]/div/div/label/select'
    browser.find_element_by_xpath(xpath_season_header).click()
    ## select season
    xpath_select_season = f'/html/body/main/div[2]/div/div[2]/div/div/div[1]/div[1]/div/div/label/select/option[{n}]'
    browser.find_element_by_xpath(xpath_select_season).click()
    return


def remove_equal_cols(df):
    "works with non-unique column names"
    dup_col_idxs = set()
    for i in range(len(df.columns)-1):
        if i in dup_col_idxs: continue
        for j in range(i+1, len(df.columns)):
            if df.iloc[:, i].equals(df.iloc[:, j]):                
                dup_col_idxs.add(j)
    df = df.iloc[:, list(set(range(len(df.columns)))-dup_col_idxs)]
    return df

# %%
list(df1.columns)
# Out:
# ['A', 'B', 'C', 'D']

# %%
## Get df from raw table

def scrape_table(browser, stat_type: str):
    """
    Scrapes stats table present on browser and returns pandas DF. 
    
    1: Traditional
    2: Advanced
    3: Misc
    4: Scoring
    5: Usage
    6: Opponent
    7: Defense
    """
    stat_table_dict = {'traditional': 1, 'advanced': 2, 'misc': 3, 'scoring': 4, 'usage': 5, 'opponent': 6, 'defense':7}
    n = stat_table_dict[stat_type]
    
    ## read in raw table data
    xpath_stats_table = '/html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[2]/div[1]'
    raw_table = browser.find_element_by_xpath(xpath_stats_table)
    table = raw_table.text.split('\n')
    
    ## columns for each table type...
    if n == 1:  # traditional
        cols = ['TEAM', 'AGE', 'GP', 'W', 'L', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'PF', 'FP', 'DD2', 'TD3', '+/-']
    
    elif n == 2:  # advanced
        cols = ['TEAM', 'AGE', 'GP', 'W', 'L', 'MIN', 'OFFRTG', 'DEFRTG', 'NETRTG', 'AST%', 'AST/TO', 'AST RATIO', 'OREB%', 'DREB%', 'REB%', 'TO RATIO', 'EFG%', 'TS%', 'USG%', 'PACE', 'PIE']
    
    elif n == 3: # misc
        cols = ['TEAM','AGE','GP','W','L','MIN','PTS OFF TO','2ND PTS','FBPS','PITP','OPP PTS OFF TO','OPP 2ND PTS','OPP FBPS','OPP PITP','BLK','BLKA','PF','PFD']

    elif n == 4: # scoring
        cols = ['TEAM', 'AGE', 'GP', 'W','L','MIN','%FGA 2PT','%FGA 3PT','%PTS 2PT','%PTS 2PT MR','%PTS 3PT','%PTS FBPS','%PTS FT','%PTS OFFTO','%PTS PITP','2FGM %AST','2FGM %UAST','3FGM %AST','3FGM %UAST','FGM %AST','FGM %UAST']
    
    elif n == 5:  # usage
        cols = ['TEAM', 'AGE', 'GP', 'W', 'L', 'MIN', 'USG%', '%FGM', '%FGA', '%3PM', '%3PA', '%FTM', '%FTA', '%OREB', '%DREB', '%REB', '%AST', '%TOV', '%STL', '%BLK', '%BLKA', '%PF', '%PFD', '%PTS']
    
#     ## MISSING DATA FROM PRIOR 2010'S
#     elif table_num == 6: # opponent
#         cols = ['TEAM','GP','W','L','MIN','OPP FGM','OPP FGA','OPP FG%','OPP 3PM','OPP 3PA','OPP 3P%','OPP FTM','OPP FTA','OPP FT%','OPP OREB','OPP DREB','OPP REB','OPP AST','OPP TOV','OPP STL','OPP BLK','OPP BLKA','OPP PF','OPP PFD','OPP PTS','+/-',]
    
    elif n == 7:  # defense
        cols = ['TEAM','AGE','GP','W','L','MIN','DEF RTG','DREB','DREB%','%DREB','STL','STL%','BLK','%BLK','OPP PTS OFF TOV','OPP PTS 2ND CHANCE','OPP PTS FB','OPP PTS PAINT','DEF WS']

    ## extract position of first player row
    for i, line in enumerate(table):
        if line and line[0] == 'A' and len(line.split(' ')) == 2:
            body = table[i:] 
            break
            
    ## parse body of table now and extract index, stats
    index, all_stats = [], []
    for i in range(0, len(body), 2):
        player = body[i]
        if len(player.split(' ')) > 0 and len(player.split(' ')) < 3:
            index.append(player)
            stats = body[i+1].split(' ')
            all_stats.append(stats)
        
    return pd.DataFrame(all_stats, index=index, columns=cols)

# %%
def scrape_combine_season_data(season: int, stat_types: list):
    
    ## set up browser
    generic_nba_stats_url = 'https://stats.nba.com/players/traditional/?sort=PTS&dir=-1'
    browser = webdriver.Firefox(executable_path="./drivers/geckodriver")
    browser.get(generic_nba_stats_url)
    time.sleep(3)  # ensure loading...
    
    dfs = []
    for stat_type in stat_types:
        select_stat_type(browser, stat_type); time.sleep(3)
        select_season(browser, season); time.sleep(3)
        sort_by_name(browser); time.sleep(3)
        select_all_pages(browser); time.sleep(3)
        df = scrape_table(browser, stat_type)
        dfs.append(df)
        time.sleep(3)
     
    ## merge all dataframes together on index and only use unique col names
    combined_stats = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True), dfs)
    ## remove the remaining duplicate columns with slightly diff names (i.e. 'DEFRTG' and 'DEF RTG')
    combined_stats = remove_equal_cols(combined_stats)
    
    ## ADD YEAR SUFFIX TO INDEX I.E. (JAMES HARDEN 19, MICHAEL JORDAN 98)
    
    return combined_stats

# %%
## TESTING
stat_types = ['traditional', 'defense', 'usage', 'advanced', 'misc', 'scoring']
# stat_types = ['traditional', 'advanced']
stats_12 = scrape_combine_season_data(2012, stat_types)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-474-6ac3eb799cfe> in <module>
#       3 stat_types = ['traditional', 'defense', 'usage', 'advanced', 'misc', 'scoring']
#       4 # stat_types = ['traditional', 'advanced']
# ----> 5 stats_12 = scrape_combine_season_data(2012, stat_types)
#
# <ipython-input-470-8bb7064e7646> in scrape_combine_season_data(season, stat_types)
#      11         select_stat_type(browser, stat_type); time.sleep(3)
#      12         select_season(browser, season); time.sleep(3)
# ---> 13         sort_by_name(browser); time.sleep(3)
#      14         select_all_pages(browser); time.sleep(3)
#      15         df = scrape_table(browser, stat_type)
#
# <ipython-input-469-f8de8fae44a7> in sort_by_name(browser)
#       3 def sort_by_name(browser):
#       4     xpath_player_sort = '/html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[2]/div[1]/table/thead/tr/th[2]'
# ----> 5     browser.find_element_by_xpath(xpath_player_sort).click()
#       6     browser.find_element_by_xpath(xpath_player_sort).click()
#       7     return
#
# ~\anaconda3\envs\nba\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\envs\nba\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\envs\nba\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\nba\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: /html/body/main/div[2]/div/div[2]/div/div/nba-stat-table/div[2]/div[1]/table/thead/tr/th[2]

# %%
stats_01.shape
# Out:
# (436, 86)

# %%
stats = remove_equal_cols(stats_01)
stats.shape
# Out:
# (436, 86)

# %%
set(stats_01.columns) - set(merge_cols)
# Out:
# {'%3PA',
#  '%3PM',
#  '%AST',
#  '%BLKA',
#  '%FGA',
#  '%FGM',
#  '%FTA',
#  '%FTM',
#  '%OREB',
#  '%PF',
#  '%PFD',
#  '%PTS',
#  '%REB',
#  '%TOV'}

# %%
## TESTING

concat_df = pd.concat(dfs, axis=1)
concat_cols = concat_df.columns


merge_df = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True, ), dfs)
merge_cols = merge_df.columns

print(len(concat_cols))
print(len(merge_cols))

print('-----')

concat_df = remove_identical_cols(concat_df)
concat_cols = concat_df.columns

merge_df = remove_identical_cols(merge_df)
merge_cols = merge_df.columns

print(len(concat_cols))
print(len(merge_cols))

print('----')

extra_cols = set(merge_cols) - set(concat_cols)
print(len(extra_cols))

## There are 2 different MIN variations (shown by double MIN col in concat_cols which are filtered out in the reduce merge)
# Out:
# 107
# 77
# -----
# 73
# 72
# ----
# 0

# %%
seen = []
for col in concat_cols:
    if col not in seen:
        seen.append(col)
    else:
        print('dup:', col)
# Out:
# dup: MIN

# %%
concat_cols.sort_values()
# Out:
# Index(['%BLK', '%DREB', '%FGA 2PT', '%FGA 3PT', '%PTS 2PT', '%PTS 2PT MR',
#        '%PTS 3PT', '%PTS FBPS', '%PTS FT', '%PTS OFFTO', '%PTS PITP', '+/-',
#        '2FGM %AST', '2FGM %UAST', '2ND PTS', '3FGM %AST', '3FGM %UAST', '3P%',
#        '3PA', '3PM', 'AGE', 'AST', 'AST RATIO', 'AST%', 'AST/TO', 'BLK',
#        'BLKA', 'DD2', 'DEF RTG', 'DEF WS', 'DREB', 'DREB%', 'EFG%', 'FBPS',
#        'FG%', 'FGA', 'FGM', 'FGM %AST', 'FGM %UAST', 'FP', 'FT%', 'FTA', 'FTM',
#        'GP', 'L', 'MIN', 'MIN', 'NETRTG', 'OFFRTG', 'OPP PTS 2ND CHANCE',
#        'OPP PTS FB', 'OPP PTS OFF TOV', 'OPP PTS PAINT', 'OREB', 'OREB%',
#        'PACE', 'PF', 'PFD', 'PIE', 'PITP', 'PTS', 'PTS OFF TO', 'REB', 'REB%',
#        'STL', 'STL%', 'TD3', 'TEAM', 'TO RATIO', 'TOV', 'TS%', 'USG%', 'W'],
#       dtype='object')

# %%
extra_cols = set(concat_cols) - set(merge_cols)
print(len(extra_cols))
# Out:
# 0

# %%
for i in list(concat_cols.sort_values()): print(i)
# Out:
# %BLK
# %DREB
# %FGA 2PT
# %FGA 3PT
# %PTS 2PT
# %PTS 2PT MR
# %PTS 3PT
# %PTS FBPS
# %PTS FT
# %PTS OFFTO
# %PTS PITP
# +/-
# 2FGM %AST
# 2FGM %UAST
# 2ND PTS
# 3FGM %AST
# 3FGM %UAST
# 3P%
# 3PA
# 3PM
# AST
# AST RATIO
# AST%
# AST/TO
# BLKA
# DD2
# DEF RTG
# DEF WS
# EFG%
# FBPS
# FG%
# FGA
# FGM
# FGM %AST
# FGM %UAST
# FP
# FT%
# FTA
# FTM
# NETRTG
# OFFRTG
# OPP PTS 2ND CHANCE
# OPP PTS FB
# OPP PTS OFF TOV
# OPP PTS PAINT
# OREB
# OREB%
# PACE
# PFD
# PIE
# PITP
# PTS
# PTS OFF TO
# REB
# REB%
# STL%
# TD3
# TO RATIO
# TOV
# TS%
# USG%

# %%
# Out:
#                      PTS  FGM   FGA   FG%  3PM  3PA   3P%  FTM   FTA   FT%  \
# Aaron McKie          6.5  2.6   6.1  43.0  0.9  2.7  32.3  0.4   0.7  62.5
# Aaron Williams      11.9  4.7  10.3  46.0  0.0  0.0   0.0  2.5   2.8  88.2
# Adonal Foyle        10.5  4.7   9.3  50.2  0.0  0.0   0.0  1.2   2.1  55.6
# Adrian Griffin      11.4  4.4  12.2  36.0  0.2  0.7  22.2  2.5   3.3  75.0
# Al Harrington       23.7  9.3  20.2  45.9  0.3  1.5  21.6  4.8   7.2  67.2
# ...                  ...  ...   ...   ...  ...  ...   ...  ...   ...   ...
# Zaza Pachulia       17.2  6.0  13.3  45.2  0.0  0.0   0.0  5.2   7.0  74.6
# Zeljko Rebraca      19.3  7.6  13.3  56.8  0.0  0.0   0.0  4.2   4.8  85.9
# Zendon Hamilton     16.3  3.5  10.2  34.4  0.0  0.0   0.0  9.3  15.3  60.4
# Zoran Planinic      22.5  8.1  18.0  44.8  1.6  4.1  37.5  4.8   6.8  69.7
# Zydrunas Ilgauskas  26.7  9.3  19.8  46.8  0.0  0.1  28.6  8.1  10.2  79.9
#
#                     ... %PTS FBPS %PTS FT %PTS OFFTO %PTS PITP 2FGM %AST  \
# Aaron McKie         ...      15.8     6.6       20.4      25.0      73.2
# Aaron Williams      ...       8.2    20.5       17.8      63.0      82.8
# Adonal Foyle        ...       6.3    11.4       12.5      79.5      64.1
# Adrian Griffin      ...      12.6    21.9       23.2      33.1      51.8
# Al Harrington       ...      11.6    20.4       18.0      53.5      45.3
# ...                 ...       ...     ...        ...       ...       ...
# Zaza Pachulia       ...       6.6    30.1       15.7      60.7      66.9
# Zeljko Rebraca      ...       2.7    21.5       11.8      59.6      66.9
# Zendon Hamilton     ...       7.8    56.9       23.5      35.3      81.8
# Zoran Planinic      ...      18.0    21.2       21.2      41.5      44.4
# Zydrunas Ilgauskas  ...       5.0    30.5       12.1      48.3      65.4
#
#                    2FGM %UAST 3FGM %AST 3FGM %UAST FGM %AST FGM %UAST
# Aaron McKie              26.8      95.0        5.0     80.3      19.7
# Aaron Williams           17.2       0.0        0.0     82.8      17.2
# Adonal Foyle             35.9       0.0        0.0     64.1      35.9
# Adrian Griffin           48.2       100        0.0     53.4      46.6
# Al Harrington            54.7      93.8        6.3     47.0      53.0
# ...                       ...       ...        ...      ...       ...
# Zaza Pachulia            33.1       0.0        0.0     66.9      33.1
# Zeljko Rebraca           33.1       0.0        0.0     66.9      33.1
# Zendon Hamilton          18.2       0.0        0.0     81.8      18.2
# Zoran Planinic           55.6      93.3        6.7     53.8      46.2
# Zydrunas Ilgauskas       34.6       100        0.0     65.5      34.5
#
# [460 rows x 61 columns]

# %%
extra_cols
# Out:
# {'AGE', 'BLK', 'DREB', 'DREB%', 'GP', 'L', 'MIN', 'PF', 'STL', 'TEAM', 'W'}

# %%
stats = pd.concat(dfs, axis=1)
print(stats.shape)

concat_dups, stats = remove_identical_cols(stats)
len(concat_dups)

print(stats.shape)

# stats = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True, ), dfs)
# print(stats.shape)

# stats = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, ), dfs)
# print(stats.shape)

# stats = remove_identical_cols(stats)
# print(stats.shape)
# Out:
# (460, 107)
# (460, 61)

# %%
# there are 107 total cols
# 30 exact name repeats

# 72 'unique' cols according to merge verison and 61 according to concat
# 16 col discpepancy

# %%
stats = pd.concat(dfs, axis=1)
print(stats.shape)

stats = remove_identical_cols(stats)
print(stats.shape)
# Out:
# (460, 107)
# ['TEAM', 'TEAM', 'TEAM', 'TEAM', 'AGE', 'AGE', 'AGE', 'AGE', 'GP', 'GP', 'GP', 'GP', 'W', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'MIN', 'MIN', 'MIN', 'MIN', 'DREB', 'STL', 'BLK', 'BLK', 'PF', 'TEAM', 'TEAM', 'TEAM', 'AGE', 'AGE', 'AGE', 'GP', 'GP', 'GP', 'W', 'W', 'W', 'L', 'L', 'L', 'MIN', 'MIN', 'MIN', 'DEFRTG', 'DREB%', 'BLK', 'OPP PTS OFF TO', 'OPP 2ND PTS', 'OPP FBPS', 'OPP PITP', 'TEAM', 'TEAM', 'AGE', 'AGE', 'GP', 'GP', 'W', 'W', 'L', 'L', 'MIN', 'MIN', 'TEAM', 'AGE', 'GP', 'W', 'L', 'MIN']
# (460, 61)

# %%
stats = pd.concat(dfs, axis=1)
cols = list(stats.columns.sort_values())
print(stats.shape); print()
seen = []
dups = {}
tot = 0
for col in cols:
    if col not in seen:
        seen.append(col)
    else:
        tot += 1
        if col not in dups:
            dups[col]=1
            
        else:
            dups[col] += 1
            
            
print(tot)
print()
dups
# Out:
# (460, 107)
#
# 30
# {'AGE': 4,
#  'BLK': 2,
#  'DREB': 1,
#  'DREB%': 1,
#  'GP': 4,
#  'L': 4,
#  'MIN': 4,
#  'PF': 1,
#  'STL': 1,
#  'TEAM': 4,
#  'W': 4}

# %%
a = {'a':1}
'a' in a
# Out:
# True

# %%
# stats = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True, ), dfs)
stats = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, ), dfs)

cols = list(stats.columns.sort_values())
print(len(cols)); print()
for col in cols: print(col)
# Out:
# 107
#
# %BLK
# %DREB
# %FGA 2PT
# %FGA 3PT
# %PTS 2PT
# %PTS 2PT MR
# %PTS 3PT
# %PTS FBPS
# %PTS FT
# %PTS OFFTO
# %PTS PITP
# +/-
# 2FGM %AST
# 2FGM %UAST
# 2ND PTS
# 3FGM %AST
# 3FGM %UAST
# 3P%
# 3PA
# 3PM
# AGE
# AGE_x
# AGE_x
# AGE_y
# AGE_y
# AST
# AST RATIO
# AST%
# AST/TO
# BLK
# BLKA
# BLK_x
# BLK_y
# DD2
# DEF RTG
# DEF WS
# DEFRTG
# DREB%_x
# DREB%_y
# DREB_x
# DREB_y
# EFG%
# FBPS
# FG%
# FGA
# FGM
# FGM %AST
# FGM %UAST
# FP
# FT%
# FTA
# FTM
# GP
# GP_x
# GP_x
# GP_y
# GP_y
# L
# L_x
# L_x
# L_y
# L_y
# MIN
# MIN_x
# MIN_x
# MIN_y
# MIN_y
# NETRTG
# OFFRTG
# OPP 2ND PTS
# OPP FBPS
# OPP PITP
# OPP PTS 2ND CHANCE
# OPP PTS FB
# OPP PTS OFF TO
# OPP PTS OFF TOV
# OPP PTS PAINT
# OREB
# OREB%
# PACE
# PFD
# PF_x
# PF_y
# PIE
# PITP
# PTS
# PTS OFF TO
# REB
# REB%
# STL%
# STL_x
# STL_y
# TD3
# TEAM
# TEAM_x
# TEAM_x
# TEAM_y
# TEAM_y
# TO RATIO
# TOV
# TS%
# USG%
# W
# W_x
# W_x
# W_y
# W_y

# %%
a = df1.copy()
a.drop(['A', 'A', 'A'], axis=1)
# Out:
#      B   C   D
# 55  B0  C0  D0
# 65  B1  C1  D1
# 75  B2  C2  D2
# 85  B3  C3  D3

# %%
combined_stats = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, ), dfs)
combined_stats.shape

dups = []
for i, col1 in enumerate(combined_stats.columns):
    for col2 in combined_stats.columns[i+1:]:
        if combined_stats[col1].equals(combined_stats[col2]):
            dups.append(col2)
combined_stats.drop(dups, inplace=True, axis=1)
combined_stats.shape
# Out:
# (460, 72)

# %%
combined_stats = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True, ), dfs)

# %%
# dups = [col for i, col in enumerate(combined_stats.columns) if combined_stats[col].equals(combined_stats[col2] for col2 in combined_stats.columns[i+1:])]

dups = []
for i, col1 in enumerate(combined_stats.columns):
    for col2 in combined_stats.columns[i+1:]:
        if combined_stats[col1].equals(combined_stats[col2]):
            print('MATCH:', col1, col2)
            dups.append(col2)
dups
# Out:
# MATCH: DEF RTG DEFRTG
# MATCH: OPP PTS 2ND CHANCE OPP 2ND PTS
# MATCH: OPP PTS FB OPP FBPS
# MATCH: OPP PTS OFF TOV OPP PTS OFF TO
# MATCH: OPP PTS PAINT OPP PITP
# ['DEFRTG', 'OPP 2ND PTS', 'OPP FBPS', 'OPP PTS OFF TO', 'OPP PITP']

# %%
combo = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True), dfs)
combo.shape
# Out:
# (460, 107)

# %%
combined_stats = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True), dfs)
combined_stats.shape
# Out:
# (460, 77)

# %%
# for i in combined_stats.columns.sort_values(): print(i)
    
for i, col1 in enumerate(combined_stats.columns):
    print('\n----------', col1)
    for col2 in combined_stats.columns[i+1:]:
        if combined_stats[col1].equals(combined_stats[col2]):
            print('MATCH WITH:', col2)
# Out:
# ---------- TEAM
#
# ---------- AGE
#
# ---------- GP
#
# ---------- W
#
# ---------- L
#
# ---------- MIN
#
# ---------- PTS
#
# ---------- FGM
#
# ---------- FGA
#
# ---------- FG%
#
# ---------- 3PM
#
# ---------- 3PA
#
# ---------- 3P%
#
# ---------- FTM
#
# ---------- FTA
#
# ---------- FT%
#
# ---------- OREB
#
# ---------- DREB
#
# ---------- REB
#
# ---------- AST
#
# ---------- TOV
#
# ---------- STL
#
# ---------- BLK
#
# ---------- PF
#
# ---------- FP
#
# ---------- DD2
#
# ---------- TD3
#
# ---------- +/-
#
# ---------- %BLK
#
# ---------- %DREB
#
# ---------- DEF RTG
# MATCH WITH: DEFRTG
#
# ---------- DEF WS
#
# ---------- DREB%
#
# ---------- OPP PTS 2ND CHANCE
# MATCH WITH: OPP 2ND PTS
#
# ---------- OPP PTS FB
# MATCH WITH: OPP FBPS
#
# ---------- OPP PTS OFF TOV
# MATCH WITH: OPP PTS OFF TO
#
# ---------- OPP PTS PAINT
# MATCH WITH: OPP PITP
#
# ---------- STL%
#
# ---------- AST RATIO
#
# ---------- AST%
#
# ---------- AST/TO
#
# ---------- DEFRTG
#
# ---------- EFG%
#
# ---------- NETRTG
#
# ---------- OFFRTG
#
# ---------- OREB%
#
# ---------- PACE
#
# ---------- PIE
#
# ---------- REB%
#
# ---------- TO RATIO
#
# ---------- TS%
#
# ---------- USG%
#
# ---------- 2ND PTS
#
# ---------- BLKA
#
# ---------- FBPS
#
# ---------- OPP 2ND PTS
#
# ---------- OPP FBPS
#
# ---------- OPP PITP
#
# ---------- OPP PTS OFF TO
#
# ---------- PFD
#
# ---------- PITP
#
# ---------- PTS OFF TO
#
# ---------- %FGA 2PT
#
# ---------- %FGA 3PT
#
# ---------- %PTS 2PT
#
# ---------- %PTS 2PT MR
#
# ---------- %PTS 3PT
#
# ---------- %PTS FBPS
#
# ---------- %PTS FT
#
# ---------- %PTS OFFTO
#
# ---------- %PTS PITP
#
# ---------- 2FGM %AST
#
# ---------- 2FGM %UAST
#
# ---------- 3FGM %AST
#
# ---------- 3FGM %UAST
#
# ---------- FGM %AST
#
# ---------- FGM %UAST

# %%
for df in dfs:
    print(df.head())
# Out:
#                TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  ...   REB  \
# Aaron McKie     PHI  32  68  35  33  48.5   6.5  2.6   6.1  43.0  ...   7.4
# Aaron Williams  TOR  33  42  13  29  50.9  11.9  4.7  10.3  46.0  ...   9.8
# Adonal Foyle    GSW  30  78  31  47  50.7  10.5  4.7   9.3  50.2  ...  12.8
# Adrian Griffin  CHI  30  69  38  31  49.9  11.4  4.4  12.2  36.0  ...  11.1
# Al Harrington   ATL  25  66  10  56  52.0  23.7  9.3  20.2  45.9  ...   9.4
#
#                 AST  TOV  STL  BLK    PF    FP DD2 TD3    +/-
# Aaron McKie     4.4  1.3  2.1  0.7   5.0  29.2   0   0    0.5
# Aaron Williams  1.3  2.8  0.8  1.3  11.4  29.2   0   0  -22.2
# Adonal Foyle    1.7  1.7  0.8  4.7   6.0  43.2   3   0   -0.8
# Adrian Griffin  4.0  2.3  3.3  0.3   5.9  39.1   0   0    3.0
# Al Harrington   4.3  4.2  1.7  0.3   5.1  43.4  12   0  -10.5
#
# [5 rows x 28 columns]
#                TEAM AGE  GP   W   L   MIN DEF RTG DREB DREB% %DREB  STL  STL%  \
# Aaron McKie     PHI  32  68  35  33  48.5    99.7  6.5  13.5  20.7  2.1  24.1
# Aaron Williams  TOR  33  42  13  29  50.9   106.4  7.0  15.2  23.1  0.8  10.2
# Adonal Foyle    GSW  30  78  31  47  50.7   102.4  7.9  15.2  24.6  0.8   9.6
# Adrian Griffin  CHI  30  69  38  31  49.9    91.1  7.1  13.8  22.2  3.3  31.6
# Al Harrington   ATL  25  66  10  56  52.0   108.0  6.5  13.9  21.3  1.7  20.9
#
#                 BLK  %BLK OPP PTS OFF TOV OPP PTS 2ND CHANCE OPP PTS FB  \
# Aaron McKie     0.7  21.8            17.4               12.7        8.7
# Aaron Williams  1.3  30.8            20.8               13.4       16.0
# Adonal Foyle    4.7  76.1            16.3               16.3       13.6
# Adrian Griffin  0.3   6.9            18.3               12.7       12.3
# Al Harrington   0.3   7.7            20.2               14.2       14.2
#
#                OPP PTS PAINT DEF WS
# Aaron McKie             34.3  0.204
# Aaron Williams          41.8  0.105
# Adonal Foyle            44.0  0.166
# Adrian Griffin          34.1  0.351
# Al Harrington           45.5  0.078
#                TEAM AGE  GP   W   L   MIN OFFRTG DEFRTG NETRTG  AST%  ...  \
# Aaron McKie     PHI  32  68  35  33  16.6  100.4   99.7    0.7  13.5  ...
# Aaron Williams  TOR  33  42  13  29   7.4   86.4  106.4  -20.0   4.9  ...
# Adonal Foyle    GSW  30  78  31  47  21.8  102.3  102.4   -0.2   4.8  ...
# Adrian Griffin  CHI  30  69  38  31   9.5   94.8   91.1    3.8  13.4  ...
# Al Harrington   ATL  25  66  10  56  38.6   97.8  108.0  -10.2  14.8  ...
#
#                AST RATIO OREB% DREB%  REB% TO RATIO  EFG%   TS%  USG%   PACE  \
# Aaron McKie         36.4   1.7  13.5   7.5     11.0  50.0  51.0   6.8  99.06
# Aaron Williams       8.4   5.5  15.2  10.1     17.9  46.0  51.8  12.8  95.28
# Adonal Foyle        12.3   9.3  15.2  12.2     12.7  50.2  51.4  10.4  94.87
# Adrian Griffin      20.0   7.2  13.8  10.4     11.3  36.6  41.9  13.6  96.64
# Al Harrington       13.4   5.7  13.9   9.6     13.1  46.8  50.8  23.6  92.35
#
#                 PIE
# Aaron McKie     6.6
# Aaron Williams  2.0
# Adonal Foyle    7.2
# Adrian Griffin  9.0
# Al Harrington   9.5
#
# [5 rows x 21 columns]
#                TEAM AGE  GP   W   L   MIN PTS OFF TO 2ND PTS FBPS  PITP  \
# Aaron McKie     PHI  32  68  35  33  48.5        1.3     0.1  1.0   1.6
# Aaron Williams  TOR  33  42  13  29  50.9        2.1     2.8  1.0   7.5
# Adonal Foyle    GSW  30  78  31  47  50.7        1.3     2.3  0.7   8.4
# Adrian Griffin  CHI  30  69  38  31  49.9        2.7     1.3  1.4   3.8
# Al Harrington   ATL  25  66  10  56  52.0        4.3     3.5  2.7  12.7
#
#                OPP PTS OFF TO OPP 2ND PTS OPP FBPS OPP PITP  BLK BLKA    PF  \
# Aaron McKie              17.4        12.7      8.7     34.3  0.7  0.5   5.0
# Aaron Williams           20.8        13.4     16.0     41.8  1.3  1.1  11.4
# Adonal Foyle             16.3        16.3     13.6     44.0  4.7  0.6   6.0
# Adrian Griffin           18.3        12.7     12.3     34.1  0.3  0.7   5.9
# Al Harrington            20.2        14.2     14.2     45.5  0.3  1.5   5.1
#
#                 PFD
# Aaron McKie     0.0
# Aaron Williams  0.0
# Adonal Foyle    0.0
# Adrian Griffin  0.0
# Al Harrington   0.0
#                TEAM AGE  GP   W   L   MIN %FGA 2PT %FGA 3PT %PTS 2PT  \
# Aaron McKie     PHI  32  68  35  33  16.6     56.3     43.7     53.9
# Aaron Williams  TOR  33  42  13  29   7.4      100      0.0     79.5
# Adonal Foyle    GSW  30  78  31  47  21.8      100      0.0     88.6
# Adrian Griffin  CHI  30  69  38  31   9.5     94.4      5.6     74.2
# Al Harrington   ATL  25  66  10  56  38.6     92.5      7.5     75.5
#
#                %PTS 2PT MR  ... %PTS FBPS %PTS FT %PTS OFFTO %PTS PITP  \
# Aaron McKie           28.9  ...      15.8     6.6       20.4      25.0
# Aaron Williams        16.4  ...       8.2    20.5       17.8      63.0
# Adonal Foyle           9.1  ...       6.3    11.4       12.5      79.5
# Adrian Griffin        41.1  ...      12.6    21.9       23.2      33.1
# Al Harrington         21.9  ...      11.6    20.4       18.0      53.5
#
#                2FGM %AST 2FGM %UAST 3FGM %AST 3FGM %UAST FGM %AST FGM %UAST
# Aaron McKie         73.2       26.8      95.0        5.0     80.3      19.7
# Aaron Williams      82.8       17.2       0.0        0.0     82.8      17.2
# Adonal Foyle        64.1       35.9       0.0        0.0     64.1      35.9
# Adrian Griffin      51.8       48.2       100        0.0     53.4      46.6
# Al Harrington       45.3       54.7      93.8        6.3     47.0      53.0
#
# [5 rows x 21 columns]

# %%
for i, col1 in enumerate(combo.columns):
    print('\n----------', col1)
    for col2 in combo.columns[i:]:
        if combo[col1].equals(combo[col2]):
            print('MATCH WITH:', col2)
# Out:
# ---------- TEAM_x
# MATCH WITH: TEAM_x
# MATCH WITH: TEAM_x
#
# ---------- AGE_x
# MATCH WITH: AGE_x
# MATCH WITH: AGE_x
#
# ---------- GP_x
# MATCH WITH: GP_x
# MATCH WITH: GP_x
#
# ---------- W_x
# MATCH WITH: W_x
# MATCH WITH: W_x
#
# ---------- L_x
# MATCH WITH: L_x
# MATCH WITH: L_x
#
# ---------- MIN_x
# MATCH WITH: MIN_x
# MATCH WITH: MIN_x
#
# ---------- PTS
# MATCH WITH: PTS
#
# ---------- FGM
# MATCH WITH: FGM
#
# ---------- FGA
# MATCH WITH: FGA
#
# ---------- FG%
# MATCH WITH: FG%
#
# ---------- 3PM
# MATCH WITH: 3PM
#
# ---------- 3PA
# MATCH WITH: 3PA
#
# ---------- 3P%
# MATCH WITH: 3P%
#
# ---------- FTM
# MATCH WITH: FTM
#
# ---------- FTA
# MATCH WITH: FTA
#
# ---------- FT%
# MATCH WITH: FT%
#
# ---------- OREB
# MATCH WITH: OREB
#
# ---------- DREB_x
# MATCH WITH: DREB_x
# MATCH WITH: DREB_y
#
# ---------- REB
# MATCH WITH: REB
#
# ---------- AST
# MATCH WITH: AST
#
# ---------- TOV
# MATCH WITH: TOV
#
# ---------- STL_x
# MATCH WITH: STL_x
# MATCH WITH: STL_y
#
# ---------- BLK_x
# MATCH WITH: BLK_x
# MATCH WITH: BLK_y
# MATCH WITH: BLK
#
# ---------- PF_x
# MATCH WITH: PF_x
# MATCH WITH: PF_y
#
# ---------- FP
# MATCH WITH: FP
#
# ---------- DD2
# MATCH WITH: DD2
#
# ---------- TD3
# MATCH WITH: TD3
#
# ---------- +/-
# MATCH WITH: +/-
#
# ---------- TEAM_y
# MATCH WITH: TEAM_y
# MATCH WITH: TEAM_y
#
# ---------- AGE_y
# MATCH WITH: AGE_y
# MATCH WITH: AGE_y
#
# ---------- GP_y
# MATCH WITH: GP_y
# MATCH WITH: GP_y
#
# ---------- W_y
# MATCH WITH: W_y
# MATCH WITH: W_y
#
# ---------- L_y
# MATCH WITH: L_y
# MATCH WITH: L_y
#
# ---------- MIN_y
# MATCH WITH: MIN_y
# MATCH WITH: MIN_y
#
# ---------- DEF RTG
# MATCH WITH: DEF RTG
# MATCH WITH: DEFRTG
#
# ---------- DREB_y
# MATCH WITH: DREB_y
#
# ---------- DREB%_x
# MATCH WITH: DREB%_x
# MATCH WITH: DREB%_y
#
# ---------- %DREB
# MATCH WITH: %DREB
#
# ---------- STL_y
# MATCH WITH: STL_y
#
# ---------- STL%
# MATCH WITH: STL%
#
# ---------- BLK_y
# MATCH WITH: BLK_y
# MATCH WITH: BLK
#
# ---------- %BLK
# MATCH WITH: %BLK
#
# ---------- OPP PTS OFF TOV
# MATCH WITH: OPP PTS OFF TOV
# MATCH WITH: OPP PTS OFF TO
#
# ---------- OPP PTS 2ND CHANCE
# MATCH WITH: OPP PTS 2ND CHANCE
# MATCH WITH: OPP 2ND PTS
#
# ---------- OPP PTS FB
# MATCH WITH: OPP PTS FB
# MATCH WITH: OPP FBPS
#
# ---------- OPP PTS PAINT
# MATCH WITH: OPP PTS PAINT
# MATCH WITH: OPP PITP
#
# ---------- DEF WS
# MATCH WITH: DEF WS
#
# ---------- TEAM_x
# MATCH WITH: TEAM_x
#
# ---------- AGE_x
# MATCH WITH: AGE_x
#
# ---------- GP_x
# MATCH WITH: GP_x
#
# ---------- W_x
# MATCH WITH: W_x
#
# ---------- L_x
# MATCH WITH: L_x
#
# ---------- MIN_x
# MATCH WITH: MIN_x
#
# ---------- OFFRTG
# MATCH WITH: OFFRTG
#
# ---------- DEFRTG
# MATCH WITH: DEFRTG
#
# ---------- NETRTG
# MATCH WITH: NETRTG
#
# ---------- AST%
# MATCH WITH: AST%
#
# ---------- AST/TO
# MATCH WITH: AST/TO
#
# ---------- AST RATIO
# MATCH WITH: AST RATIO
#
# ---------- OREB%
# MATCH WITH: OREB%
#
# ---------- DREB%_y
# MATCH WITH: DREB%_y
#
# ---------- REB%
# MATCH WITH: REB%
#
# ---------- TO RATIO
# MATCH WITH: TO RATIO
#
# ---------- EFG%
# MATCH WITH: EFG%
#
# ---------- TS%
# MATCH WITH: TS%
#
# ---------- USG%
# MATCH WITH: USG%
#
# ---------- PACE
# MATCH WITH: PACE
#
# ---------- PIE
# MATCH WITH: PIE
#
# ---------- TEAM_y
# MATCH WITH: TEAM_y
#
# ---------- AGE_y
# MATCH WITH: AGE_y
#
# ---------- GP_y
# MATCH WITH: GP_y
#
# ---------- W_y
# MATCH WITH: W_y
#
# ---------- L_y
# MATCH WITH: L_y
#
# ---------- MIN_y
# MATCH WITH: MIN_y
#
# ---------- PTS OFF TO
# MATCH WITH: PTS OFF TO
#
# ---------- 2ND PTS
# MATCH WITH: 2ND PTS
#
# ---------- FBPS
# MATCH WITH: FBPS
#
# ---------- PITP
# MATCH WITH: PITP
#
# ---------- OPP PTS OFF TO
# MATCH WITH: OPP PTS OFF TO
#
# ---------- OPP 2ND PTS
# MATCH WITH: OPP 2ND PTS
#
# ---------- OPP FBPS
# MATCH WITH: OPP FBPS
#
# ---------- OPP PITP
# MATCH WITH: OPP PITP
#
# ---------- BLK
# MATCH WITH: BLK
#
# ---------- BLKA
# MATCH WITH: BLKA
#
# ---------- PF_y
# MATCH WITH: PF_y
#
# ---------- PFD
# MATCH WITH: PFD
#
# ---------- TEAM
# MATCH WITH: TEAM
#
# ---------- AGE
# MATCH WITH: AGE
#
# ---------- GP
# MATCH WITH: GP
#
# ---------- W
# MATCH WITH: W
#
# ---------- L
# MATCH WITH: L
#
# ---------- MIN
# MATCH WITH: MIN
#
# ---------- %FGA 2PT
# MATCH WITH: %FGA 2PT
#
# ---------- %FGA 3PT
# MATCH WITH: %FGA 3PT
#
# ---------- %PTS 2PT
# MATCH WITH: %PTS 2PT
#
# ---------- %PTS 2PT MR
# MATCH WITH: %PTS 2PT MR
#
# ---------- %PTS 3PT
# MATCH WITH: %PTS 3PT
#
# ---------- %PTS FBPS
# MATCH WITH: %PTS FBPS
#
# ---------- %PTS FT
# MATCH WITH: %PTS FT
#
# ---------- %PTS OFFTO
# MATCH WITH: %PTS OFFTO
#
# ---------- %PTS PITP
# MATCH WITH: %PTS PITP
#
# ---------- 2FGM %AST
# MATCH WITH: 2FGM %AST
#
# ---------- 2FGM %UAST
# MATCH WITH: 2FGM %UAST
#
# ---------- 3FGM %AST
# MATCH WITH: 3FGM %AST
#
# ---------- 3FGM %UAST
# MATCH WITH: 3FGM %UAST
#
# ---------- FGM %AST
# MATCH WITH: FGM %AST
#
# ---------- FGM %UAST
# MATCH WITH: FGM %UAST

# %%
## TESTING

stat_types = ['traditional', 'defense', 'advanced', 'misc', 'scoring']
# stat_types = ['traditional', 'advanced']
res = scrape_combine_season_data(2004, stat_types)

# %%
## investigating duplicate column names

stat_types = ['traditional', 'defense', 'advanced', 'misc', 'scoring']
dups = ['TEAM', 'AGE', 'GP', 'W', 'L', 'MIN']
dfs = [res[k] for k in res]
for i, (df, stat_type) in enumerate(zip(dfs, stat_types), 1):
    print('\n-------------------', stat_type, '---------------------')
    
    for j, other in enumerate(dfs[i:]):
        print('\n---------other:', stat_types[i+j])
        for col1 in df.columns:
            if col1 not in dups:
                for col2 in other.columns:
                    if df[col1].equals(other[col2]):
#                     if col1 == col2:
                        print('MATCH:', col1, col2)
        
        
        
        
        
#         for col2 in dfs[i+1].columns:
#             if col1 not in dups:
#                 if col1 == col2:
#                     print('\nMATCHING COL')
#                     print(col1, 'and', col2)
# Out:
# ------------------- traditional ---------------------
#
# ---------other: defense
# MATCH: DREB DREB
# MATCH: STL STL
# MATCH: BLK BLK
#
# ---------other: advanced
#
# ---------other: misc
# MATCH: BLK BLK
# MATCH: PF PF
#
# ---------other: scoring
#
# ------------------- defense ---------------------
#
# ---------other: advanced
# MATCH: DEF RTG DEFRTG
# MATCH: DREB% DREB%
#
# ---------other: misc
# MATCH: BLK BLK
# MATCH: OPP PTS OFF TOV OPP PTS OFF TO
# MATCH: OPP PTS 2ND CHANCE OPP 2ND PTS
# MATCH: OPP PTS FB OPP FBPS
# MATCH: OPP PTS PAINT OPP PITP
#
# ---------other: scoring
#
# ------------------- advanced ---------------------
#
# ---------other: misc
#
# ---------other: scoring
#
# ------------------- misc ---------------------
#
# ---------other: scoring
#
# ------------------- scoring ---------------------

# %%
## function that takes in df and

combo
# Out:
#                    TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  ...  \
# Aaron McKie         PHI  32  68  35  33  48.5   6.5  2.6   6.1  43.0  ...
# Aaron Williams      TOR  33  42  13  29  50.9  11.9  4.7  10.3  46.0  ...
# Adonal Foyle        GSW  30  78  31  47  50.7  10.5  4.7   9.3  50.2  ...
# Adrian Griffin      CHI  30  69  38  31  49.9  11.4  4.4  12.2  36.0  ...
# Al Harrington       ATL  25  66  10  56  52.0  23.7  9.3  20.2  45.9  ...
# ...                 ...  ..  ..  ..  ..   ...   ...  ...   ...   ...  ...
# Zaza Pachulia       MIL  21  74  27  47  52.5  17.2  6.0  13.3  45.2  ...
# Zeljko Rebraca      LAC  33  58  27  31  53.0  19.3  7.6  13.3  56.8  ...
# Zendon Hamilton     MIL  30  16   7   9  51.4  16.3  3.5  10.2  34.4  ...
# Zoran Planinic      NJN  22  43  20  23  53.0  22.5  8.1  18.0  44.8  ...
# Zydrunas Ilgauskas  CLE  30  78  40  38  53.0  26.7  9.3  19.8  46.8  ...
#
#                    AST RATIO OREB% DREB%  REB% TO RATIO  EFG%   TS%  USG%  \
# Aaron McKie             36.4   1.7  13.5   7.5     11.0  50.0  51.0   6.8
# Aaron Williams           8.4   5.5  15.2  10.1     17.9  46.0  51.8  12.8
# Adonal Foyle            12.3   9.3  15.2  12.2     12.7  50.2  51.4  10.4
# Adrian Griffin          20.0   7.2  13.8  10.4     11.3  36.6  41.9  13.6
# Al Harrington           13.4   5.7  13.9   9.6     13.1  46.8  50.8  23.6
# ...                      ...   ...   ...   ...      ...   ...   ...   ...
# Zaza Pachulia           10.6  10.1  18.9  14.5     12.3  45.2  52.6  16.6
# Zeljko Rebraca           7.5   5.8  14.3  10.3     14.1  56.8  62.5  16.0
# Zendon Hamilton          8.2  11.9  16.8  14.3     16.4  34.4  48.0  18.9
# Zoran Planinic          15.3   3.8  10.2   7.0     14.3  49.1  53.4  21.9
# Zydrunas Ilgauskas       6.7  11.8  14.9  13.4     12.7  46.9  55.0  24.2
#
#                      PACE   PIE
# Aaron McKie         99.06   6.6
# Aaron Williams      95.28   2.0
# Adonal Foyle        94.87   7.2
# Adrian Griffin      96.64   9.0
# Al Harrington       92.35   9.5
# ...                   ...   ...
# Zaza Pachulia       91.50   9.6
# Zeljko Rebraca      90.38  10.2
# Zendon Hamilton     93.37   3.5
# Zoran Planinic      90.86   8.8
# Zydrunas Ilgauskas  90.66  11.3
#
# [460 rows x 49 columns]

# %%
for i, df, stat_type in enumerate(dfs) stat_types:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-211-7f820c790396> in <module>
# ----> 1 for i, df, stat_type in enumerate(dfs), stat_types:
#       2     print(i)
#
# ValueError: too many values to unpack (expected 3)

# %%
for i, df, stat_type in enumerate(zip(dfs, stat_types)):
    print(stat_type)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-212-160b869f0c3f> in <module>
# ----> 1 for i, df, stat_type in enumerate(zip(dfs, stat_types)):
#       2     print(stat_type)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
aa = [1,1,1]
bb = [2,2,2]
for i, (a, b) in enumerate(zip(aa, bb)):
    print(a)
# Out:
# 1
# 1
# 1

# %%
a = (zip(enumerate(dfs), stat_types))
for x in a:
    print(type(x))
    print(x)
    print('-------------')
# Out:
# <class 'tuple'>
# ((0,                    TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  ...  \
# Aaron McKie         PHI  32  68  35  33  48.5   6.5  2.6   6.1  43.0  ...
# Aaron Williams      TOR  33  42  13  29  50.9  11.9  4.7  10.3  46.0  ...
# Adonal Foyle        GSW  30  78  31  47  50.7  10.5  4.7   9.3  50.2  ...
# Adrian Griffin      CHI  30  69  38  31  49.9  11.4  4.4  12.2  36.0  ...
# Al Harrington       ATL  25  66  10  56  52.0  23.7  9.3  20.2  45.9  ...
# ...                 ...  ..  ..  ..  ..   ...   ...  ...   ...   ...  ...
# Zaza Pachulia       MIL  21  74  27  47  52.5  17.2  6.0  13.3  45.2  ...
# Zeljko Rebraca      LAC  33  58  27  31  53.0  19.3  7.6  13.3  56.8  ...
# Zendon Hamilton     MIL  30  16   7   9  51.4  16.3  3.5  10.2  34.4  ...
# Zoran Planinic      NJN  22  43  20  23  53.0  22.5  8.1  18.0  44.8  ...
# Zydrunas Ilgauskas  CLE  30  78  40  38  53.0  26.7  9.3  19.8  46.8  ...
#
#                      REB  AST  TOV  STL  BLK    PF    FP DD2 TD3    +/-
# Aaron McKie          7.4  4.4  1.3  2.1  0.7   5.0  29.2   0   0    0.5
# Aaron Williams       9.8  1.3  2.8  0.8  1.3  11.4  29.2   0   0  -22.2
# Adonal Foyle        12.8  1.7  1.7  0.8  4.7   6.0  43.2   3   0   -0.8
# Adrian Griffin      11.1  4.0  2.3  3.3  0.3   5.9  39.1   0   0    3.0
# Al Harrington        9.4  4.3  4.2  1.7  0.3   5.1  43.4  12   0  -10.5
# ...                  ...  ...  ...  ...  ...   ...   ...  ..  ..    ...
# Zaza Pachulia       14.2  2.3  2.6  1.7  1.3   6.2  43.8   1   0   -0.3
# Zeljko Rebraca      10.5  1.5  2.8  0.7  2.3   7.4  40.4   2   0    0.9
# Zendon Hamilton     13.4  1.9  3.8  1.6  0.6   8.3  38.1   0   0  -10.9
# Zoran Planinic       7.2  4.6  4.3  2.6  0.0   7.9  41.5   0   0   -4.7
# Zydrunas Ilgauskas  13.6  2.0  3.9  1.1  3.3   6.3  55.5  24   0    2.6
#
# [460 rows x 28 columns]), 'traditional')
# -------------
# <class 'tuple'>
# ((1,                    TEAM AGE  GP   W   L   MIN DEF RTG DREB DREB% %DREB  STL  \
# Aaron McKie         PHI  32  68  35  33  48.5    99.7  6.5  13.5  20.7  2.1
# Aaron Williams      TOR  33  42  13  29  50.9   106.4  7.0  15.2  23.1  0.8
# Adonal Foyle        GSW  30  78  31  47  50.7   102.4  7.9  15.2  24.6  0.8
# Adrian Griffin      CHI  30  69  38  31  49.9    91.1  7.1  13.8  22.2  3.3
# Al Harrington       ATL  25  66  10  56  52.0   108.0  6.5  13.9  21.3  1.7
# ...                 ...  ..  ..  ..  ..   ...     ...  ...   ...   ...  ...
# Zaza Pachulia       MIL  21  74  27  47  52.5   104.2  9.3  18.9  30.6  1.7
# Zeljko Rebraca      LAC  33  58  27  31  53.0    99.9  7.7  14.3  23.9  0.7
# Zendon Hamilton     MIL  30  16   7   9  51.4   111.5  7.7  16.8  29.6  1.6
# Zoran Planinic      NJN  22  43  20  23  53.0    96.0  5.2  10.2  16.3  2.6
# Zydrunas Ilgauskas  CLE  30  78  40  38  53.0   103.4  7.6  14.9  23.5  1.1
#
#                     STL%  BLK  %BLK OPP PTS OFF TOV OPP PTS 2ND CHANCE  \
# Aaron McKie         24.1  0.7  21.8            17.4               12.7
# Aaron Williams      10.2  1.3  30.8            20.8               13.4
# Adonal Foyle         9.6  4.7  76.1            16.3               16.3
# Adrian Griffin      31.6  0.3   6.9            18.3               12.7
# Al Harrington       20.9  0.3   7.7            20.2               14.2
# ...                  ...  ...   ...             ...                ...
# Zaza Pachulia       20.7  1.3  47.2            18.2               15.2
# Zeljko Rebraca       9.6  2.3  41.2            16.5               15.9
# Zendon Hamilton     16.1  0.6  22.2            19.2               14.7
# Zoran Planinic      29.4  0.0   0.0            18.4               15.7
# Zydrunas Ilgauskas  12.8  3.3  53.6            16.2               13.8
#
#                    OPP PTS FB OPP PTS PAINT DEF WS
# Aaron McKie               8.7          34.3  0.204
# Aaron Williams           16.0          41.8  0.105
# Adonal Foyle             13.6          44.0  0.166
# Adrian Griffin           12.3          34.1  0.351
# Al Harrington            14.2          45.5  0.078
# ...                       ...           ...    ...
# Zaza Pachulia            15.1          46.4  0.140
# Zeljko Rebraca           10.2          39.6  0.211
# Zendon Hamilton          17.3          39.0  0.022
# Zoran Planinic           13.0          34.4  0.280
# Zydrunas Ilgauskas       13.8          41.7  0.155
#
# [460 rows x 19 columns]), 'defense')
# -------------
# <class 'tuple'>
# ((2,                    TEAM AGE  GP   W   L   MIN OFFRTG DEFRTG NETRTG  AST%  ...  \
# Aaron McKie         PHI  32  68  35  33  16.6  100.4   99.7    0.7  13.5  ...
# Aaron Williams      TOR  33  42  13  29   7.4   86.4  106.4  -20.0   4.9  ...
# Adonal Foyle        GSW  30  78  31  47  21.8  102.3  102.4   -0.2   4.8  ...
# Adrian Griffin      CHI  30  69  38  31   9.5   94.8   91.1    3.8  13.4  ...
# Al Harrington       ATL  25  66  10  56  38.6   97.8  108.0  -10.2  14.8  ...
# ...                 ...  ..  ..  ..  ..   ...    ...    ...    ...   ...  ...
# Zaza Pachulia       MIL  21  74  27  47  18.9  104.0  104.2   -0.2   7.1  ...
# Zeljko Rebraca      LAC  33  58  27  31  16.0  100.3   99.9    0.3   4.9  ...
# Zendon Hamilton     MIL  30  16   7   9  10.1  100.6  111.5  -10.9   6.3  ...
# Zoran Planinic      NJN  22  43  20  23  11.9   91.8   96.0   -4.2  18.5  ...
# Zydrunas Ilgauskas  CLE  30  78  40  38  33.5  106.2  103.4    2.7   6.5  ...
#
#                    AST RATIO OREB% DREB%  REB% TO RATIO  EFG%   TS%  USG%  \
# Aaron McKie             36.4   1.7  13.5   7.5     11.0  50.0  51.0   6.8
# Aaron Williams           8.4   5.5  15.2  10.1     17.9  46.0  51.8  12.8
# Adonal Foyle            12.3   9.3  15.2  12.2     12.7  50.2  51.4  10.4
# Adrian Griffin          20.0   7.2  13.8  10.4     11.3  36.6  41.9  13.6
# Al Harrington           13.4   5.7  13.9   9.6     13.1  46.8  50.8  23.6
# ...                      ...   ...   ...   ...      ...   ...   ...   ...
# Zaza Pachulia           10.6  10.1  18.9  14.5     12.3  45.2  52.6  16.6
# Zeljko Rebraca           7.5   5.8  14.3  10.3     14.1  56.8  62.5  16.0
# Zendon Hamilton          8.2  11.9  16.8  14.3     16.4  34.4  48.0  18.9
# Zoran Planinic          15.3   3.8  10.2   7.0     14.3  49.1  53.4  21.9
# Zydrunas Ilgauskas       6.7  11.8  14.9  13.4     12.7  46.9  55.0  24.2
#
#                      PACE   PIE
# Aaron McKie         99.06   6.6
# Aaron Williams      95.28   2.0
# Adonal Foyle        94.87   7.2
# Adrian Griffin      96.64   9.0
# Al Harrington       92.35   9.5
# ...                   ...   ...
# Zaza Pachulia       91.50   9.6
# Zeljko Rebraca      90.38  10.2
# Zendon Hamilton     93.37   3.5
# Zoran Planinic      90.86   8.8
# Zydrunas Ilgauskas  90.66  11.3
#
# [460 rows x 21 columns]), 'advanced')
# -------------
# <class 'tuple'>
# ((3,                    TEAM AGE  GP   W   L   MIN PTS OFF TO 2ND PTS FBPS  PITP  \
# Aaron McKie         PHI  32  68  35  33  48.5        1.3     0.1  1.0   1.6
# Aaron Williams      TOR  33  42  13  29  50.9        2.1     2.8  1.0   7.5
# Adonal Foyle        GSW  30  78  31  47  50.7        1.3     2.3  0.7   8.4
# Adrian Griffin      CHI  30  69  38  31  49.9        2.7     1.3  1.4   3.8
# Al Harrington       ATL  25  66  10  56  52.0        4.3     3.5  2.7  12.7
# ...                 ...  ..  ..  ..  ..   ...        ...     ...  ...   ...
# Zaza Pachulia       MIL  21  74  27  47  52.5        2.7     5.1  1.1  10.5
# Zeljko Rebraca      LAC  33  58  27  31  53.0        2.3     2.9  0.5  11.5
# Zendon Hamilton     MIL  30  16   7   9  51.4        3.8     4.8  1.3   5.8
# Zoran Planinic      NJN  22  43  20  23  53.0        4.8     2.1  4.0   9.3
# Zydrunas Ilgauskas  CLE  30  78  40  38  53.0        3.2     6.4  1.3  12.9
#
#                    OPP PTS OFF TO OPP 2ND PTS OPP FBPS OPP PITP  BLK BLKA  \
# Aaron McKie                  17.4        12.7      8.7     34.3  0.7  0.5
# Aaron Williams               20.8        13.4     16.0     41.8  1.3  1.1
# Adonal Foyle                 16.3        16.3     13.6     44.0  4.7  0.6
# Adrian Griffin               18.3        12.7     12.3     34.1  0.3  0.7
# Al Harrington                20.2        14.2     14.2     45.5  0.3  1.5
# ...                           ...         ...      ...      ...  ...  ...
# Zaza Pachulia                18.2        15.2     15.1     46.4  1.3  1.6
# Zeljko Rebraca               16.5        15.9     10.2     39.6  2.3  1.3
# Zendon Hamilton              19.2        14.7     17.3     39.0  0.6  2.6
# Zoran Planinic               18.4        15.7     13.0     34.4  0.0  2.0
# Zydrunas Ilgauskas           16.2        13.8     13.8     41.7  3.3  1.5
#
#                       PF  PFD
# Aaron McKie          5.0  0.0
# Aaron Williams      11.4  0.0
# Adonal Foyle         6.0  0.0
# Adrian Griffin       5.9  0.0
# Al Harrington        5.1  0.0
# ...                  ...  ...
# Zaza Pachulia        6.2  0.0
# Zeljko Rebraca       7.4  0.1
# Zendon Hamilton      8.3  0.0
# Zoran Planinic       7.9  0.0
# Zydrunas Ilgauskas   6.3  0.0
#
# [460 rows x 18 columns]), 'misc')
# -------------
# <class 'tuple'>
# ((4,                    TEAM AGE  GP   W   L   MIN %FGA 2PT %FGA 3PT %PTS 2PT  \
# Aaron McKie         PHI  32  68  35  33  16.6     56.3     43.7     53.9
# Aaron Williams      TOR  33  42  13  29   7.4      100      0.0     79.5
# Adonal Foyle        GSW  30  78  31  47  21.8      100      0.0     88.6
# Adrian Griffin      CHI  30  69  38  31   9.5     94.4      5.6     74.2
# Al Harrington       ATL  25  66  10  56  38.6     92.5      7.5     75.5
# ...                 ...  ..  ..  ..  ..   ...      ...      ...      ...
# Zaza Pachulia       MIL  21  74  27  47  18.9     99.7      0.3     69.9
# Zeljko Rebraca      LAC  33  58  27  31  16.0      100      0.0     78.5
# Zendon Hamilton     MIL  30  16   7   9  10.1      100      0.0     43.1
# Zoran Planinic      NJN  22  43  20  23  11.9     77.0     23.0     58.1
# Zydrunas Ilgauskas  CLE  30  78  40  38  33.5     99.3      0.7     69.1
#
#                    %PTS 2PT MR  ... %PTS FBPS %PTS FT %PTS OFFTO %PTS PITP  \
# Aaron McKie               28.9  ...      15.8     6.6       20.4      25.0
# Aaron Williams            16.4  ...       8.2    20.5       17.8      63.0
# Adonal Foyle               9.1  ...       6.3    11.4       12.5      79.5
# Adrian Griffin            41.1  ...      12.6    21.9       23.2      33.1
# Al Harrington             21.9  ...      11.6    20.4       18.0      53.5
# ...                        ...  ...       ...     ...        ...       ...
# Zaza Pachulia              9.2  ...       6.6    30.1       15.7      60.7
# Zeljko Rebraca            18.9  ...       2.7    21.5       11.8      59.6
# Zendon Hamilton            7.8  ...       7.8    56.9       23.5      35.3
# Zoran Planinic            16.6  ...      18.0    21.2       21.2      41.5
# Zydrunas Ilgauskas        20.8  ...       5.0    30.5       12.1      48.3
#
#                    2FGM %AST 2FGM %UAST 3FGM %AST 3FGM %UAST FGM %AST  \
# Aaron McKie             73.2       26.8      95.0        5.0     80.3
# Aaron Williams          82.8       17.2       0.0        0.0     82.8
# Adonal Foyle            64.1       35.9       0.0        0.0     64.1
# Adrian Griffin          51.8       48.2       100        0.0     53.4
# Al Harrington           45.3       54.7      93.8        6.3     47.0
# ...                      ...        ...       ...        ...      ...
# Zaza Pachulia           66.9       33.1       0.0        0.0     66.9
# Zeljko Rebraca          66.9       33.1       0.0        0.0     66.9
# Zendon Hamilton         81.8       18.2       0.0        0.0     81.8
# Zoran Planinic          44.4       55.6      93.3        6.7     53.8
# Zydrunas Ilgauskas      65.4       34.6       100        0.0     65.5
#
#                    FGM %UAST
# Aaron McKie             19.7
# Aaron Williams          17.2
# Adonal Foyle            35.9
# Adrian Griffin          46.6
# Al Harrington           53.0
# ...                      ...
# Zaza Pachulia           33.1
# Zeljko Rebraca          33.1
# Zendon Hamilton         18.2
# Zoran Planinic          46.2
# Zydrunas Ilgauskas      34.5
#
# [460 rows x 21 columns]), 'scoring')
# -------------

# %%
## checking the repeating columsn to make sure their are no overlapping names for diff stats

# dfs = [res[k] for k in res]
for i, stat_type in enumerate(stat_types):
    if i < len(dfs):
        for col1 in res[stat_type].columns:
            for col2 in res[stat_types[i+1]].columns:
                if res[col1].equals(res[col2]):
                    print('EQUAL COLS')
                    print(f'{col1} and {col2}\n')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-dd0374295b04> in <module>
#       6         for col1 in res[stat_type].columns:
#       7             for col2 in res[stat_types[i+1]].columns:
# ----> 8                 if res[col1].equals(res[col2]):
#       9                     print('EQUAL COLS')
#      10                     print(f'{col1} and {col2}\n')
#
# KeyError: 'TEAM'

# %%
res.keys()
# Out:
# dict_keys(['traditional', 'defense', 'advanced', 'misc', 'scoring'])

# %%
for k in res:
    print(len(res[k].index))
# Out:
# 460
# 460
# 460
# 460
# 460

# %%
dfs = [res[k] for k in res]
len(dfs)
# Out:
# 5

# %%
tot_cols = sum([len(res[k].columns) for k in res])
print(tot_cols)
# Out:
# 107
# 28
# 19
# 21
# 18
# 21

# %%
a = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True), dfs)
# a[]

# %%
cols_to_use = df2.columns.difference(df.columns)

b =

# %%
b = reduce(lambda left, right: pd.merge(left, right[right.columns.difference(left.columns)], left_index=True, right_index=True), dfs)

# %%
for col in b.columns: print(col)
# Out:
# TEAM
# AGE
# GP
# W
# L
# MIN
# PTS
# FGM
# FGA
# FG%
# 3PM
# 3PA
# 3P%
# FTM
# FTA
# FT%
# OREB
# DREB
# REB
# AST
# TOV
# STL
# BLK
# PF
# FP
# DD2
# TD3
# +/-
# %BLK
# %DREB
# DEF RTG
# DEF WS
# DREB%
# OPP PTS 2ND CHANCE
# OPP PTS FB
# OPP PTS OFF TOV
# OPP PTS PAINT
# STL%
# AST RATIO
# AST%
# AST/TO
# DEFRTG
# EFG%
# NETRTG
# OFFRTG
# OREB%
# PACE
# PIE
# REB%
# TO RATIO
# TS%
# USG%
# 2ND PTS
# BLKA
# FBPS
# OPP 2ND PTS
# OPP FBPS
# OPP PITP
# OPP PTS OFF TO
# PFD
# PITP
# PTS OFF TO
# %FGA 2PT
# %FGA 3PT
# %PTS 2PT
# %PTS 2PT MR
# %PTS 3PT
# %PTS FBPS
# %PTS FT
# %PTS OFFTO
# %PTS PITP
# 2FGM %AST
# 2FGM %UAST
# 3FGM %AST
# 3FGM %UAST
# FGM %AST
# FGM %UAST

# %%
for col in a.columns:
    print(col)
# Out:
# TEAM_x
# AGE_x
# GP_x
# W_x
# L_x
# MIN_x
# PTS
# FGM
# FGA
# FG%
# 3PM
# 3PA
# 3P%
# FTM
# FTA
# FT%
# OREB
# DREB_x
# REB
# AST
# TOV
# STL_x
# BLK_x
# PF_x
# FP
# DD2
# TD3
# +/-
# TEAM_y
# AGE_y
# GP_y
# W_y
# L_y
# MIN_y
# DEF RTG
# DREB_y
# DREB%_x
# %DREB
# STL_y
# STL%
# BLK_y
# %BLK
# OPP PTS OFF TOV
# OPP PTS 2ND CHANCE
# OPP PTS FB
# OPP PTS PAINT
# DEF WS
# TEAM_x
# AGE_x
# GP_x
# W_x
# L_x
# MIN_x
# OFFRTG
# DEFRTG
# NETRTG
# AST%
# AST/TO
# AST RATIO
# OREB%
# DREB%_y
# REB%
# TO RATIO
# EFG%
# TS%
# USG%
# PACE
# PIE
# TEAM_y
# AGE_y
# GP_y
# W_y
# L_y
# MIN_y
# PTS OFF TO
# 2ND PTS
# FBPS
# PITP
# OPP PTS OFF TO
# OPP 2ND PTS
# OPP FBPS
# OPP PITP
# BLK
# BLKA
# PF_y
# PFD
# TEAM
# AGE
# GP
# W
# L
# MIN
# %FGA 2PT
# %FGA 3PT
# %PTS 2PT
# %PTS 2PT MR
# %PTS 3PT
# %PTS FBPS
# %PTS FT
# %PTS OFFTO
# %PTS PITP
# 2FGM %AST
# 2FGM %UAST
# 3FGM %AST
# 3FGM %UAST
# FGM %AST
# FGM %UAST

# %%
tr_idx = tr.index
ad_idx = ad.index

tr.index.equals(ad_idx)
# Out:
# True

# %%
combined = pd.concat([tr, ad], axis=1)
combined.head()
# Out:
#                TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  ...  \
# Aaron McKie     PHI  32  68  35  33  48.5   6.5  2.6   6.1  43.0  ...
# Aaron Williams  TOR  33  42  13  29  50.9  11.9  4.7  10.3  46.0  ...
# Adonal Foyle    GSW  30  78  31  47  50.7  10.5  4.7   9.3  50.2  ...
# Adrian Griffin  CHI  30  69  38  31  49.9  11.4  4.4  12.2  36.0  ...
# Al Harrington   ATL  25  66  10  56  52.0  23.7  9.3  20.2  45.9  ...
#
#                AST RATIO OREB% DREB%  REB% TO RATIO  EFG%   TS%  USG%   PACE  \
# Aaron McKie         36.4   1.7  13.5   7.5     11.0  50.0  51.0   6.8  99.06
# Aaron Williams       8.4   5.5  15.2  10.1     17.9  46.0  51.8  12.8  95.28
# Adonal Foyle        12.3   9.3  15.2  12.2     12.7  50.2  51.4  10.4  94.87
# Adrian Griffin      20.0   7.2  13.8  10.4     11.3  36.6  41.9  13.6  96.64
# Al Harrington       13.4   5.7  13.9   9.6     13.1  46.8  50.8  23.6  92.35
#
#                 PIE
# Aaron McKie     6.6
# Aaron Williams  2.0
# Adonal Foyle    7.2
# Adrian Griffin  9.0
# Al Harrington   9.5
#
# [5 rows x 49 columns]

# %%
print(len(tr.columns))
print(len(ad.columns))
# Out:
# 28
# 21

# %%
## seeing how to concat the stat tables from same season

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[55, 65, 75, 85])

df2 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3'],
                           'E': ['E0', 'E1', 'E2', 'E3']},
                        index=[55, 65, 75, 85])


# combined = pd.concat([df1, df2], axis=1)

# combined = combined.loc[:, combined.columns.unique()]
# combined = pd.merge(df1, df2, how='left')
# combined = df1.join(df2, how=index)
# combined = pd.merge(df1, df2, left_index=True, right_index=True)
combined = pd.merge(df1, df2, how='right')
combined = pd.merge(df1, df2)
combined



combined = pd.merge(df1, df2, left_index=True, right_index=True)
combined
# Out:
#    A_x B_x C_x D_x A_y B_y C_y D_y   E
# 55  A0  B0  C0  D0  A0  B0  C0  D0  E0
# 65  A1  B1  C1  D1  A1  B1  C1  D1  E1
# 75  A2  B2  C2  D2  A2  B2  C2  D2  E2
# 85  A3  B3  C3  D3  A3  B3  C3  D3  E3

# %%
combined['A_x'].equals(combined['A_y'])
# Out:
# True

# %%
combined.iloc[:, 0].equals(combined.iloc[:, 4])
# Out:
# True

# %%
print(combined.columns.duplicated())
print(combined.columns)
print(~combined.columns.duplicated())
# Out:
# [False False False False  True  True  True  True False]
# Index(['A', 'B', 'C', 'D', 'A', 'B', 'C', 'D', 'E'], dtype='object')
# [ True  True  True  True False False False False  True]

# %%
## Dropping duplicate columns
a = combo.loc[:, ~combo.columns.duplicated()]

# %%
a.columns
# Out:
# Index(['TEAM', 'AGE', 'GP', 'W', 'L', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM',
#        '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV',
#        'STL', 'BLK', 'PF', 'FP', 'DD2', 'TD3', '+/-', 'OFFRTG', 'DEFRTG',
#        'NETRTG', 'AST%', 'AST/TO', 'AST RATIO', 'OREB%', 'DREB%', 'REB%',
#        'TO RATIO', 'EFG%', 'TS%', 'USG%', 'PACE', 'PIE'],
#       dtype='object')

# %%
len(res['traditional'])
len(res['advanced'])

tr = res['traditional']
ad = res['advanced']

print(tr.head())
ad.head()
# Out:
#                TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  ...   REB  \
# Aaron McKie     PHI  32  68  35  33  48.5   6.5  2.6   6.1  43.0  ...   7.4
# Aaron Williams  TOR  33  42  13  29  50.9  11.9  4.7  10.3  46.0  ...   9.8
# Adonal Foyle    GSW  30  78  31  47  50.7  10.5  4.7   9.3  50.2  ...  12.8
# Adrian Griffin  CHI  30  69  38  31  49.9  11.4  4.4  12.2  36.0  ...  11.1
# Al Harrington   ATL  25  66  10  56  52.0  23.7  9.3  20.2  45.9  ...   9.4
#
#                 AST  TOV  STL  BLK    PF    FP DD2 TD3    +/-
# Aaron McKie     4.4  1.3  2.1  0.7   5.0  29.2   0   0    0.5
# Aaron Williams  1.3  2.8  0.8  1.3  11.4  29.2   0   0  -22.2
# Adonal Foyle    1.7  1.7  0.8  4.7   6.0  43.2   3   0   -0.8
# Adrian Griffin  4.0  2.3  3.3  0.3   5.9  39.1   0   0    3.0
# Al Harrington   4.3  4.2  1.7  0.3   5.1  43.4  12   0  -10.5
#
# [5 rows x 28 columns]
#                TEAM AGE  GP   W   L   MIN OFFRTG DEFRTG NETRTG  AST%  ...  \
# Aaron McKie     PHI  32  68  35  33  16.6  100.4   99.7    0.7  13.5  ...
# Aaron Williams  TOR  33  42  13  29   7.4   86.4  106.4  -20.0   4.9  ...
# Adonal Foyle    GSW  30  78  31  47  21.8  102.3  102.4   -0.2   4.8  ...
# Adrian Griffin  CHI  30  69  38  31   9.5   94.8   91.1    3.8  13.4  ...
# Al Harrington   ATL  25  66  10  56  38.6   97.8  108.0  -10.2  14.8  ...
#
#                AST RATIO OREB% DREB%  REB% TO RATIO  EFG%   TS%  USG%   PACE  \
# Aaron McKie         36.4   1.7  13.5   7.5     11.0  50.0  51.0   6.8  99.06
# Aaron Williams       8.4   5.5  15.2  10.1     17.9  46.0  51.8  12.8  95.28
# Adonal Foyle        12.3   9.3  15.2  12.2     12.7  50.2  51.4  10.4  94.87
# Adrian Griffin      20.0   7.2  13.8  10.4     11.3  36.6  41.9  13.6  96.64
# Al Harrington       13.4   5.7  13.9   9.6     13.1  46.8  50.8  23.6  92.35
#
#                 PIE
# Aaron McKie     6.6
# Aaron Williams  2.0
# Adonal Foyle    7.2
# Adrian Griffin  9.0
# Al Harrington   9.5
#
# [5 rows x 21 columns]
