# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import seaborn as sns; sns.set()

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Build lineup dataset that has the pts_diff and then 300+ cols for merged numerical stat profile of each player wrt previous season
#
# Steps
# - Isolate numeric features for player dataset
# - cull lineup data to lineups where all players have entries for the prev season in the player dataset
# - get the player stat profile for each lineup
# - combine valid lineup dataframe with pts_diff with the lineup combined player stat profiles
#   - keep the lineup mins played data
# - Write out dataset

# %%
df = pd.read_csv('datasets/master_players_stats_bio_clusters_pca.csv', index_col=0)
df.shape
# Out:
# (6541, 145)

# %% [markdown]
# ### Isolate numeric features that can be used

# %%
dropcols = list(df.columns[df.columns.str.contains('pc_')]) + list(df.columns[df.columns.str.contains('cluster_')]) 
df_num = df.drop(dropcols, axis=1)
df_num.shape

df_num.dtypes.value_counts()

df_num.select_dtypes('O').columns
df_num.drop(['pos', 'team_id', 'salary', 'nationality'], axis=1, inplace=True)
## keep player_id for merging later
df_num.shape
# Out:
# (6541, 92)
# float64    77
# int64      10
# object      5
# dtype: int64
# Index(['player_id', 'pos', 'team_id', 'salary', 'nationality'], dtype='object')
# (6541, 88)

# %%
sorted(df_num.columns)

## leaving in clustering label
# Out:
# ['age',
#  'and1s_per_min',
#  'ast_pct',
#  'ast_per_poss',
#  'astd_pts_per_min',
#  'avg_dist',
#  'blk_pct',
#  'blk_per_poss',
#  'bpm',
#  'dbpm',
#  'def_rtg',
#  'drawn_shooting_per_min',
#  'drb_pct',
#  'drb_per_poss',
#  'dws',
#  'fg2_pct',
#  'fg2_per_poss',
#  'fg2a_per_poss',
#  'fg3_heave',
#  'fg3_pct',
#  'fg3_per_poss',
#  'fg3a_heave',
#  'fg3a_per_fga_pct',
#  'fg3a_per_poss',
#  'fg_dunk_per_min',
#  'fg_pct',
#  'fg_pct_00_03',
#  'fg_pct_03_10',
#  'fg_pct_10_16',
#  'fg_pct_16_xx',
#  'fg_pct_corner3',
#  'fg_pct_fg2a',
#  'fg_pct_fg3a',
#  'fg_per_poss',
#  'fga_per_poss',
#  'fouls_offensive_per_min',
#  'fouls_shooting_per_min',
#  'ft_pct',
#  'ft_per_poss',
#  'fta_per_fga_pct',
#  'fta_per_poss',
#  'g',
#  'gs',
#  'height',
#  'label',
#  'mp',
#  'obpm',
#  'off_rtg',
#  'orb_pct',
#  'orb_per_poss',
#  'own_shots_blk_per_min',
#  'ows',
#  'pct_ast_fg2',
#  'pct_ast_fg3',
#  'pct_c',
#  'pct_fg3a_corner3',
#  'pct_fga_00_03',
#  'pct_fga_03_10',
#  'pct_fga_10_16',
#  'pct_fga_16_xx',
#  'pct_fga_dunk',
#  'pct_fga_fg2a',
#  'pct_fga_fg3a',
#  'pct_pf',
#  'pct_pg',
#  'pct_sf',
#  'pct_sg',
#  'per',
#  'pf_per_poss',
#  'player_id',
#  'plus_minus_net',
#  'plus_minus_on',
#  'pts_per_poss',
#  'stl_pct',
#  'stl_per_poss',
#  'tov_bad_pass_per_min',
#  'tov_lost_ball_per_min',
#  'tov_pct',
#  'tov_per_poss',
#  'trb_pct',
#  'trb_per_poss',
#  'ts_pct',
#  'usg_pct',
#  'vorp',
#  'weight',
#  'ws',
#  'ws_per_48',
#  'year']

# %%
df_line = pd.read_csv('datasets/master_4man_lineup_clusters_2000_2020.csv', index_col=0)
df_line.shape
# Out:
# (5222, 51)

# %% [markdown]
# ### Drop 2000 and all columns but `diff_pts` as player season data starts in 2000 and I'm using a 1 year lag

# %%
df_line = df_line[df_line['year'] > 2000].copy()
df_line = df_line[['diff_pts', 'year', 'player_ids', 'mp']].copy()
df_line
# Out:
#                                                     diff_pts  year  \
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...       3.6  2001
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...       1.2  2002
# S. Abdur-Rahim | N. Mohammed | I. Newble | J. T...      -2.7  2002
# S. Abdur-Rahim | D. Johnson | I. Newble | J. Te...       3.4  2002
# S. Abdur-Rahim | D. Johnson | N. Mohammed | I. ...      -0.6  2002
# ...                                                      ...   ...
# T. Ariza | B. Beal | T. Bryant | T. Satoranský ...      -0.5  2019
# B. Beal | T. Bryant | J. Green | T. Satoranský ...      -1.3  2019
# T. Ariza | T. Bryant | J. Green | T. Satoranský...      -0.4  2019
# B. Beal | M. Morris | O. Porter | J. Wall WAS 2019      -0.8  2019
# T. Ariza | B. Beal | J. Green | B. Portis WAS 2019      -0.9  2019
#
#                                                                                     player_ids  \
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...  mcleoro01, mutomdi01, terryja01, wrighlo02
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...  abdursh01, johnsde03, mohamna01, terryja01
# S. Abdur-Rahim | N. Mohammed | I. Newble | J. T...  abdursh01, mohamna01, newblir01, terryja01
# S. Abdur-Rahim | D. Johnson | I. Newble | J. Te...  abdursh01, johnsde03, newblir01, terryja01
# S. Abdur-Rahim | D. Johnson | N. Mohammed | I. ...  abdursh01, johnsde03, mohamna01, newblir01
# ...                                                                                        ...
# T. Ariza | B. Beal | T. Bryant | T. Satoranský ...   arizatr01, bealbr01, bryanth01, satorto01
# B. Beal | T. Bryant | J. Green | T. Satoranský ...   bealbr01, bryanth01, greenje02, satorto01
# T. Ariza | T. Bryant | J. Green | T. Satoranský...  arizatr01, bryanth01, greenje02, satorto01
# B. Beal | M. Morris | O. Porter | J. Wall WAS 2019    bealbr01, morrima02, porteot01, walljo01
# T. Ariza | B. Beal | J. Green | B. Portis WAS 2019   arizatr01, bealbr01, greenje02, portibo01
#
#                                                             mp
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...  410.583333
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...  665.516667
# S. Abdur-Rahim | N. Mohammed | I. Newble | J. T...  591.433333
# S. Abdur-Rahim | D. Johnson | I. Newble | J. Te...  566.183333
# S. Abdur-Rahim | D. Johnson | N. Mohammed | I. ...  492.583333
# ...                                                        ...
# T. Ariza | B. Beal | T. Bryant | T. Satoranský ...  460.150000
# B. Beal | T. Bryant | J. Green | T. Satoranský ...  443.250000
# T. Ariza | T. Bryant | J. Green | T. Satoranský...  359.783333
# B. Beal | M. Morris | O. Porter | J. Wall WAS 2019  342.833333
# T. Ariza | B. Beal | J. Green | B. Portis WAS 2019  311.550000
#
# [4935 rows x 4 columns]

# %% [markdown]
# ## Func for building merged player stat profile

# %%
def check_if_valid_lineup(lineup, df_players):
    player_ids = lineup['player_ids'].split(', ')
    year = lineup['year'] - 1    
    for pid in player_ids:
        if df_players[(df_players['player_id']==pid) & (df_players['year']==year)].empty:
            return False
    return True

# l1 = df_line.iloc[0]
# check_if_valid_lineup(l1, df)

# %%
df_players = df_num.copy()
indices = df_line.apply(lambda lineup: check_if_valid_lineup(lineup, df_players), axis=1)

# %%
indices.value_counts()
# Out:
# True     3356
# False    1579
# dtype: int64

# %%
## checking that a player is actually missing
pid = 'abdursh01'
pid = 'mohamna01'
pid = 'newblir01'  # missing

year = 2001
player = df_players[(df_players['player_id']==pid) & (df_players['year']==year)]
player
# Out:
# Empty DataFrame
# Columns: [player_id, age, g, mp, per, ts_pct, fg3a_per_fga_pct, fta_per_fga_pct, orb_pct, drb_pct, trb_pct, ast_pct, stl_pct, blk_pct, tov_pct, usg_pct, ows, dws, ws, ws_per_48, obpm, dbpm, bpm, vorp, year, avg_dist, fg3_heave, fg3a_heave, fg_dunk_per_min, fg_pct, fg_pct_00_03, fg_pct_03_10, fg_pct_10_16, fg_pct_16_xx, fg_pct_corner3, fg_pct_fg2a, fg_pct_fg3a, pct_ast_fg2, pct_ast_fg3, pct_fg3a_corner3, pct_fga_00_03, pct_fga_03_10, pct_fga_10_16, pct_fga_16_xx, pct_fga_dunk, pct_fga_fg2a, pct_fga_fg3a, and1s_per_min, astd_pts_per_min, drawn_shooting_per_min, fouls_offensive_per_min, fouls_shooting_per_min, own_shots_blk_per_min, pct_pg, pct_sg, pct_sf, pct_pf, pct_c, plus_minus_net, plus_minus_on, tov_bad_pass_per_min, tov_lost_ball_per_min, ast_per_poss, blk_per_poss, def_rtg, drb_per_poss, fg2_pct, fg2_per_poss, fg2a_per_poss, fg3_pct, fg3_per_poss, fg3a_per_poss, fg_per_poss, fga_per_poss, ft_pct, ft_per_poss, fta_per_poss, gs, off_rtg, orb_per_poss, pf_per_poss, pts_per_poss, stl_per_poss, tov_per_poss, trb_per_poss, height, weight, label]
# Index: []
#
# [0 rows x 88 columns]

# %%
df_valid_line = df_line[indices].copy()
df_valid_line.shape
# Out:
# (3356, 4)

# %% [markdown]
# ## Need to build the player stat profile now for each valid lineup

# %%
def build_lineup_stat_profile(lineup, df_players):
    player_ids = lineup['player_ids'].split(', ')
    year = lineup['year'] - 1
    stats = []
    for pid in player_ids:
        player = df_players[(df_players['player_id']==pid) & (df_players['year']==year)]
#         stats.append(player.drop('player_id', axis=1).values)
        stats.append(player.values)
    return reduce(lambda left, right: np.append(left, right), stats)

# %% [markdown]
# ### Build lineup series and combine with valid lineup df

# %%
lineup_stat_profile_series = df_valid_line.apply(lambda lineup: build_lineup_stat_profile(lineup, df_players), axis=1)
lineup_stat_profiles = [np.array(lineup_stat_profile_series[row]) for row in range(len(lineup_stat_profile_series))]
df_lineup_stat_profiles = pd.DataFrame(lineup_stat_profiles, index=df_valid_line.index)
df_lineups_with_player_stats = df_valid_line.merge(df_lineup_stat_profiles, left_index=True, right_index=True, sort=False)

# %%
df_lineups_with_player_stats.shape
df_lineups_with_player_stats.head()
# df_lineups_with_player_stats.drop('year', axis=1, inplace=True)
df_lineups_with_player_stats.drop(df_lineups_with_player_stats.select_dtypes('O').columns, axis=1, inplace=True)
df_lineups_with_player_stats.shape
df_lineups_with_player_stats.head()
# Out:
# (3368, 351)
#                                                     diff_pts  year  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...       7.2  2010
# A. Afflalo | C. Anthony | C. Billups | K. Marti...       7.8  2011
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...       4.8  2010
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...       4.0  2011
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...      -3.8  2016
#
#                                                              mp   1   2     3  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   598.850000  23  74  1234
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   351.216667  24  82  2221
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  1073.500000  23  74  1234
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...   807.683333  24  82  2221
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...   953.283333  29  78  2502
#
#                                                        4      5      6      7  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   8.9  0.548  0.357  0.237
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  10.9  0.576  0.426  0.168
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...   8.9  0.548  0.357  0.237
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  10.9  0.576  0.426  0.168
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  10.7  0.533  0.377  0.224
#
#                                                     ...    342  343  344  \
# lineup                                              ...
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  ...  104.0  2.0  4.8
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  ...  101.0  3.6  4.7
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  ...  120.0  3.7  5.6
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  ...  124.0  3.1  5.2
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  ...  117.0  5.9  3.8
#
#                                                      345  346  347   348  349  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  18.5  2.3  2.5   9.5   81
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  17.0  1.8  2.3  13.9   81
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  22.8  1.9  3.0  12.1   73
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  20.9  2.1  2.3  11.5   73
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  17.6  0.5  2.3  12.3   84
#
#                                                     350  351
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  234    2
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  234    2
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  250    0
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  250    7
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  281    7
#
# [5 rows x 351 columns]
# (3368, 351)
#                                                     diff_pts  year  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...       7.2  2010
# A. Afflalo | C. Anthony | C. Billups | K. Marti...       7.8  2011
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...       4.8  2010
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...       4.0  2011
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...      -3.8  2016
#
#                                                              mp   1   2     3  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   598.850000  23  74  1234
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   351.216667  24  82  2221
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  1073.500000  23  74  1234
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...   807.683333  24  82  2221
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...   953.283333  29  78  2502
#
#                                                        4      5      6      7  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   8.9  0.548  0.357  0.237
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  10.9  0.576  0.426  0.168
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...   8.9  0.548  0.357  0.237
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  10.9  0.576  0.426  0.168
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  10.7  0.533  0.377  0.224
#
#                                                     ...    342  343  344  \
# lineup                                              ...
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  ...  104.0  2.0  4.8
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  ...  101.0  3.6  4.7
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  ...  120.0  3.7  5.6
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  ...  124.0  3.1  5.2
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  ...  117.0  5.9  3.8
#
#                                                      345  346  347   348  349  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  18.5  2.3  2.5   9.5   81
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  17.0  1.8  2.3  13.9   81
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  22.8  1.9  3.0  12.1   73
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  20.9  2.1  2.3  11.5   73
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  17.6  0.5  2.3  12.3   84
#
#                                                     350  351
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  234    2
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  234    2
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  250    0
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  250    7
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  281    7
#
# [5 rows x 351 columns]

# %% [markdown]
# ## Write out

# %%
df_lineups_with_player_stats.to_csv('datasets/4man_lineups_with_player_stat_profiles.csv')

# %%
df_lineup_stat_profiles.select_dtypes('O').head()
# lineup_stat_profile_series
# Out:
#                                                           0          88   \
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...  mcleoro01  mutomdi01
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...  abdursh01  johnsde03
# S. Abdur-Rahim | N. Mohammed | J. Terry | J. Va...  abdursh01  mohamna01
# S. Abdur-Rahim | D. Glover | N. Mohammed | J. T...  abdursh01  glovedi01
# S. Abdur-Rahim | T. Kukoč | N. Mohammed | J. Te...  abdursh01  kukocto01
#
#                                                           176        264
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...  terryja01  wrighlo02
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...  mohamna01  terryja01
# S. Abdur-Rahim | N. Mohammed | J. Terry | J. Va...  terryja01  vaughja01
# S. Abdur-Rahim | D. Glover | N. Mohammed | J. T...  mohamna01  terryja01
# S. Abdur-Rahim | T. Kukoč | N. Mohammed | J. Te...  mohamna01  terryja01

# %% [markdown]
# ### Check that stats and index match wrt player ids

# %%
df_lineup_player_stats.select_dtypes('O')
# Out:
#                                                                                     player_ids  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01, anthoca01, billuch01, martike01
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01, anthoca01, billuch01, martike01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01, anthoca01, billuch01, hilarne01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01, anthoca01, billuch01, hilarne01
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  afflaar01, anthoca01, caldejo01, lopezro01
# ...                                                                                        ...
# Ö. Aşık | J. Harden | C. Parsons | P. Patterson...   asikom01, hardeja01, parsoch01, pattepa01
# Ö. Aşık | J. Harden | J. Lin | C. Parsons HOU 2013     asikom01, hardeja01, linje01, parsoch01
# Ö. Aşık | J. Harden | J. Lin | C. Parsons HOU 2014     asikom01, hardeja01, linje01, parsoch01
# Ö. Aşık | J. Harden | J. Lin | P. Patterson HOU...     asikom01, hardeja01, linje01, pattepa01
# Ö. Aşık | J. Lin | C. Parsons | P. Patterson HO...     asikom01, linje01, parsoch01, pattepa01
#
#                                                             0         88  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01  anthoca01
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01  anthoca01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01  anthoca01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01  anthoca01
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  afflaar01  anthoca01
# ...                                                       ...        ...
# Ö. Aşık | J. Harden | C. Parsons | P. Patterson...   asikom01  hardeja01
# Ö. Aşık | J. Harden | J. Lin | C. Parsons HOU 2013   asikom01  hardeja01
# Ö. Aşık | J. Harden | J. Lin | C. Parsons HOU 2014   asikom01  hardeja01
# Ö. Aşık | J. Harden | J. Lin | P. Patterson HOU...   asikom01  hardeja01
# Ö. Aşık | J. Lin | C. Parsons | P. Patterson HO...   asikom01    linje01
#
#                                                           176        264
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  billuch01  martike01
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  billuch01  martike01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  billuch01  hilarne01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  billuch01  hilarne01
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  caldejo01  lopezro01
# ...                                                       ...        ...
# Ö. Aşık | J. Harden | C. Parsons | P. Patterson...  parsoch01  pattepa01
# Ö. Aşık | J. Harden | J. Lin | C. Parsons HOU 2013    linje01  parsoch01
# Ö. Aşık | J. Harden | J. Lin | C. Parsons HOU 2014    linje01  parsoch01
# Ö. Aşık | J. Harden | J. Lin | P. Patterson HOU...    linje01  pattepa01
# Ö. Aşık | J. Lin | C. Parsons | P. Patterson HO...  parsoch01  pattepa01
#
# [3368 rows x 5 columns]

# %%
df_lineup_player_stats = df_valid_line.copy()
df_lineup_player_stats = df_lineup_player_stats.merge(df_lineup_stat_profiles, left_index=True, right_index=True)
df_lineup_player_stats.shape
df_lineup_player_stats.head()
# Out:
# (3368, 355)
#                                                     diff_pts  year  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...       7.2  2010
# A. Afflalo | C. Anthony | C. Billups | K. Marti...       7.8  2011
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...       4.8  2010
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...       4.0  2011
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...      -3.8  2016
#
#                                                                                     player_ids  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01, anthoca01, billuch01, martike01
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01, anthoca01, billuch01, martike01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01, anthoca01, billuch01, hilarne01
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01, anthoca01, billuch01, hilarne01
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  afflaar01, anthoca01, caldejo01, lopezro01
#
#                                                             0   1   2     3  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01  23  74  1234
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  afflaar01  24  82  2221
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01  23  74  1234
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  afflaar01  24  82  2221
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  afflaar01  29  78  2502
#
#                                                        4      5      6  ...  \
# lineup                                                                  ...
# A. Afflalo | C. Anthony | C. Billups | K. Marti...   8.9  0.548  0.357  ...
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  10.9  0.576  0.426  ...
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...   8.9  0.548  0.357  ...
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  10.9  0.576  0.426  ...
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  10.7  0.533  0.377  ...
#
#                                                       342  343  344   345  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  104.0  2.0  4.8  18.5
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  101.0  3.6  4.7  17.0
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  120.0  3.7  5.6  22.8
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  124.0  3.1  5.2  20.9
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  117.0  5.9  3.8  17.6
#
#                                                     346  347   348  349  350  \
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  2.3  2.5   9.5   81  234
# A. Afflalo | C. Anthony | C. Billups | K. Marti...  1.8  2.3  13.9   81  234
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  1.9  3.0  12.1   73  250
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...  2.1  2.3  11.5   73  250
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...  0.5  2.3  12.3   84  281
#
#                                                     351
# lineup
# A. Afflalo | C. Anthony | C. Billups | K. Marti...    2
# A. Afflalo | C. Anthony | C. Billups | K. Marti...    2
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...    0
# A. Afflalo | C. Anthony | C. Billups | N. Hilár...    7
# A. Afflalo | C. Anthony | J. Calderón | R. Lope...    7
#
# [5 rows x 355 columns]

# %%
df_valid_line
# Out:
#                                                     diff_pts  year  \
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...       3.6  2001
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...       1.2  2002
# S. Abdur-Rahim | N. Mohammed | J. Terry | J. Va...     -10.4  2002
# S. Abdur-Rahim | D. Glover | N. Mohammed | J. T...     -13.8  2002
# S. Abdur-Rahim | T. Kukoč | N. Mohammed | J. Te...      -5.2  2002
# ...                                                      ...   ...
# B. Beal | K. Oubre | O. Porter | J. Wall WAS 2018       14.8  2018
# B. Beal | M. Gortat | K. Oubre | O. Porter WAS ...       4.1  2018
# T. Ariza | B. Beal | J. Green | T. Satoranský W...      -2.5  2019
# B. Beal | M. Morris | O. Porter | J. Wall WAS 2019      -0.8  2019
# T. Ariza | B. Beal | J. Green | B. Portis WAS 2019      -0.9  2019
#
#                                                                                     player_ids
# lineup
# R. McLeod | D. Mutombo | J. Terry | L. Wright A...  mcleoro01, mutomdi01, terryja01, wrighlo02
# S. Abdur-Rahim | D. Johnson | N. Mohammed | J. ...  abdursh01, johnsde03, mohamna01, terryja01
# S. Abdur-Rahim | N. Mohammed | J. Terry | J. Va...  abdursh01, mohamna01, terryja01, vaughja01
# S. Abdur-Rahim | D. Glover | N. Mohammed | J. T...  abdursh01, glovedi01, mohamna01, terryja01
# S. Abdur-Rahim | T. Kukoč | N. Mohammed | J. Te...  abdursh01, kukocto01, mohamna01, terryja01
# ...                                                                                        ...
# B. Beal | K. Oubre | O. Porter | J. Wall WAS 2018     bealbr01, oubreke01, porteot01, walljo01
# B. Beal | M. Gortat | K. Oubre | O. Porter WAS ...   bealbr01, gortama01, oubreke01, porteot01
# T. Ariza | B. Beal | J. Green | T. Satoranský W...   arizatr01, bealbr01, greenje02, satorto01
# B. Beal | M. Morris | O. Porter | J. Wall WAS 2019    bealbr01, morrima02, porteot01, walljo01
# T. Ariza | B. Beal | J. Green | B. Portis WAS 2019   arizatr01, bealbr01, greenje02, portibo01
#
# [3356 rows x 3 columns]

# %%
len(df_players.columns) * 4 - 4
# Out:
# 348

# %%
l1 = df_valid_line.iloc[0]
l1

l1_profile = build_lineup_stat_profile(l1, df_players)
len(l1_profile)
# Out:
# diff_pts                                             3.6
# year                                                2001
# player_ids    mcleoro01, mutomdi01, terryja01, wrighlo02
# Name: R. McLeod | D. Mutombo | J. Terry | L. Wright ATL 2001, dtype: object
# 348

# %%
df_players = df_num.copy()
df_players.dtypes.value_counts()
# Out:
# float64    77
# int64      10
# object      1
# dtype: int64

# %%
pid = 'mohamna01'
year = 2001
player = df_players[(df_players['player_id']==pid) & (df_players['year']==year)]
# a= []
# a.append(player.to_numpy()[0])
a = player.to_numpy()

# %%
b = np.append(a, ['Yooo', 'Hello, there'])
pid = 'mohamna01'
year = 2002
c = df_players[(df_players['player_id']==pid) & (df_players['year']==year)].values
pid = 'mohamna01'
year = 2004
g = df_players[(df_players['player_id']==pid) & (df_players['year']==year)].values
# c.values

# d = np.append(b, c.values)

h = [a,c,g]
from functools import reduce

i = reduce(lambda left, right: np.append(left, right), h)
i

# f = np.append(a, c)
# f
# Out:
# array(['mohamna01', 23, 58, 912, 19.2, 0.52, 0.003, 0.341, 14.1, 23.6,
#        18.8, 3.9, 1.7, 2.8, 13.1, 24.0, 1.1, 1.4, 2.5, 0.129, -0.2, -1.3,
#        -1.5, 0.1, 2001, 5.3, 0, 0, 0.03399122807017544,
#        0.47700000000000004, 0.642, 0.316, 0.342, 0.278, 0.0, 0.478, 0.0,
#        0.636, 0.0, 0.0, 0.485, 0.266, 0.198, 0.049, 0.08900000000000001,
#        0.997, 0.003, 0.015350877192982457, 0.0449561403508772,
#        0.0668859649122807, 0.009868421052631578, 0.0756578947368421,
#        0.042763157894736836, 0.0, 0.0, 0.0, 22.0, 78.0, -0.5, -1.0,
#        0.01644736842105263, 0.03179824561403509, 1.1, 2.0, 99.0, 11.0,
#        0.478, 10.1, 21.1, 0.0, 0.0, 0.1, 10.1, 21.2, 0.706, 5.1, 7.2, 22,
#        103.0, 6.6, 6.5, 25.3, 1.7, 3.7, 17.6, 72, 221, 7, 'mohamna01', 24,
#        82, 2168, 14.0, 0.49, 0.001, 0.311, 12.7, 21.6, 17.1, 2.6, 1.5,
#        2.1, 12.7, 19.4, 0.9, 2.4, 3.3, 0.07200000000000001, -2.2, -1.6,
#        -3.8, -1.0, 2002, 5.8, 0, 1, 0.026752767527675275, 0.461, 0.583,
#        0.33299999999999996, 0.4, 0.271, 0.0, 0.462, 0.0, 0.626, 0.0, 0.0,
#        0.47100000000000003, 0.23600000000000002, 0.22399999999999998,
#        0.067, 0.09699999999999999, 0.9990000000000001, 0.001,
#        0.007380073800738006, 0.03367158671586716, 0.04381918819188192,
#        0.00922509225092251, 0.06595940959409594, 0.03920664206642067, 0.0,
#        0.0, 0.0, 21.0, 79.0, -4.2, -6.7, 0.017988929889298892,
#        0.01614391143911439, 0.8, 1.5, 104.0, 9.9, 0.462, 7.9, 17.2, 0.0,
#        0.0, 0.0, 7.9, 17.2, 0.617, 3.3, 5.3, 73, 100.0, 5.8, 6.1, 19.2,
#        1.5, 2.8, 15.7, 72, 221, 7, 'mohamna01', 26, 80, 1611, 16.1, 0.542,
#        0.0, 0.358, 12.8, 20.7, 16.8, 4.0, 1.8, 2.4, 14.9, 18.3, 1.8, 1.9,
#        3.7, 0.11, -0.5, -0.9, -1.4, 0.3, 2004, 5.4, 0, 0,
#        0.02731222842954686, 0.521, 0.63, 0.46, 0.44, 0.259, 0.0, 0.521,
#        0.0, 0.606, 0.0, 0.0, 0.447, 0.318, 0.17800000000000002, 0.057,
#        0.102, 1.0, 0.0, 0.010552451893234015, 0.0446927374301676,
#        0.04655493482309125, 0.010552451893234015, 0.07200496585971446,
#        0.02917442582247052, 0.0, 0.0, 0.0, 6.0, 94.0, -3.9, -6.3,
#        0.01365611421477343, 0.022967101179391682, 1.2, 1.7, 102.0, 9.8,
#        0.521, 8.1, 15.6, 0.0, 0.0, 0.0, 8.1, 15.6, 0.5920000000000001,
#        3.3, 5.6, 24, 104.0, 5.9, 6.4, 19.5, 1.8, 3.2, 15.6, 72, 221, 7],
#       dtype=object)
