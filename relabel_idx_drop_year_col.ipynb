# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/clean_data.csv', index_col=0)

# %%
df.set_index(df.index.astype(str)[:-3] +  ' ' + str(season)[-4:], inplace=True)
# Out:
# 'A.C. Green 96'

# %%
## add full to index ... makes player seasons appear in order when sorting
df.index = df.index.map(lambda x: x[:-2] + '20' + x[-2:] if int(x[-2:]) < 20 else x[:-2] + '19' + x[-2:])

# %%
df.drop('YEAR', axis=1, inplace=True)

# %%
## saving reformmated index and dropping the year col (can add for analysis later)
df.to_csv('data/clean_data.csv')

# %%
df['%REB'].sort_values(ascending=False)[0:20]
# Out:
# DeAndre Jordan 2017      51.7
# Andre Drummond 2019      51.5
# Andre Drummond 2017      51.5
# Andre Drummond 2018      50.0
# Reggie Evans 2010        49.8
# Andre Drummond 2016      49.8
# Reggie Evans 2012        49.8
# Ed Davis 2018            47.7
# Hassan Whiteside 2017    47.6
# Hassan Whiteside 2019    47.3
# Hassan Whiteside 2018    47.2
# DeAndre Jordan 2014      47.2
# Hassan Whiteside 2014    47.1
# Andre Drummond 2014      47.0
# DeAndre Jordan 2016      46.7
# Andre Drummond 2015      46.6
# Danny Fortson 1998       46.5
# Hassan Whiteside 2016    46.4
# Ben Wallace 2002         46.2
# Marcus Camby 2010        46.0
# Name: %REB, dtype: float64

# %%
sns.scatterplot(x=df['3PM'], y=df['REB']);
